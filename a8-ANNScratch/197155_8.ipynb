# %% [markdown]
# ## DSc Lab Assignment 8
# ##### Name: Indira Nandepu
# ##### Section: A
# ##### Roll no: 197155

# %%
# Importing the required modules
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### Helper functions used to build the neural network

# %%
def ReLU(z):
    # ReLU, on input x, returns 0 if x is non positive, and x itself if x is positive
    a = np.maximum(0, z)
    # returning the activation
    return a


# Initializes the parameters
def initparameters(layerSizes):
    parameters = {}
    for i in range(1, len(layerSizes)):
        parameters['W' + str(i)] = np.random.randn(layerSizes[i], layerSizes[i-1])*0.01
        parameters['B' + str(i)] = np.random.randn(layerSizes[i],1)*0.01
    return parameters


# Performs Forward propagation
def forwardProp(X_train, parameters):
    layers = len(parameters)//2
    values = {}
    for i in range(1, layers+1):
        if i==1:
            values['Z' + str(i)] = np.dot(parameters['W' + str(i)], X_train) + parameters['B' + str(i)]
            values['A' + str(i)] = ReLU(values['Z' + str(i)])
        else:
            values['Z' + str(i)] = np.dot(parameters['W' + str(i)], values['A' + str(i-1)]) + parameters['B' + str(i)]
            if i==layers:
                values['A' + str(i)] = values['Z' + str(i)]
            else:
                values['A' + str(i)] = ReLU(values['Z' + str(i)])
    return values


# Cost computation
def computeCost(vals, Y_train):
    layers = len(vals)//2
    Y_pred = vals['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost


# Backpropagation
def backwardProp(parameters, vals, X_train, Y_train):
    layers = len(parameters)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        if i==layers:
            dA = 1/m * (vals['A' + str(i)] - Y_train)
            dZ = dA
        else:
            dA = np.dot(parameters['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(vals['A' + str(i)]>=0, 1, 0))
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,vals['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads


# Updates the parameters
def updparameters(parameters, gradients, alpha):
    layers = len(parameters)//2
    parameters_updated = {}
    for i in range(1,layers+1):
        parameters_updated['W' + str(i)] = parameters['W' + str(i)] - alpha * gradients['W' + str(i)]
        parameters_updated['B' + str(i)] = parameters['B' + str(i)] - alpha * gradients['B' + str(i)]
    return parameters_updated


# Training the model
def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    parameters = initparameters(layer_sizes)
    for i in range(num_iters):
        values = forwardProp(X_train.T, parameters)
        cost = computeCost(values, Y_train.T)
        grads = backwardProp(parameters, values,X_train.T, Y_train.T)
        parameters = updparameters(parameters, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' : ' + str(cost) + '\n')
    return parameters


# Predicting the values
def predict(X, params):
    vals = forwardProp(X.T, params)
    predictions = vals['A' + str(len(vals)//2)].T
    return predictions


# Computing the accuracy
def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    trainVals = forwardProp(X_train.T, params)
    testVals = forwardProp(X_test.T, params)
    trainAcc = np.sqrt(mean_squared_error(Y_train, trainVals['A' + str(len(layer_sizes)-1)].T))
    testAcc = np.sqrt(mean_squared_error(Y_test, testVals['A' + str(len(layer_sizes)-1)].T))
    return trainAcc, testAcc

# %% [markdown]
# #### 1. Making predictions to the boston housing dataset using the Neural network built from scratch

# %%
# Initialising the hyper-parameters
layer_sizes = [13, 8, 4, 1]                                                       #set layer sizes, do not change the size of the first and last layer 
num_iters = 50                                                                 #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.05

# loading the csv file
boston_dataset =  pd.read_csv('boston.csv')

n=boston_dataset.shape[1]
m=boston_dataset.shape[0]

x_train=np.array(boston_dataset.iloc[:int(0.8*m),:n-1])
y_train=np.array(boston_dataset.iloc[:int(0.8*m),-1])  
x_test=np.array(boston_dataset.iloc[int(0.8*m):,:n-1])
y_test=np.array(boston_dataset.iloc[int(0.8*m):,-1])

params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)

y_predict = predict(x_test,params)

import math
error = math.sqrt(np.mean((y_test - y_predict)**2))

print("RMS error of the model=> ", error)
# Out:
# Cost at iteration 1 : 334.7289955854144
#
# Cost at iteration 2 : 334.65401575230965
#
# Cost at iteration 3 : 334.57882818968
#
# Cost at iteration 4 : 334.50340246347645
#
# Cost at iteration 5 : 334.4277148754548
#
# Cost at iteration 6 : 334.35175527055253
#
# Cost at iteration 7 : 334.27547886580226
#
# Cost at iteration 8 : 334.1988389982693
#
# Cost at iteration 9 : 334.12178876786265
#
# Cost at iteration 10 : 334.04424399169454
#
# Cost at iteration 11 : 333.96607195825453
#
# Cost at iteration 12 : 333.88714411624113
#
# Cost at iteration 13 : 333.8073371124016
#
# Cost at iteration 14 : 333.7264743108448
#
# Cost at iteration 15 : 333.64433911620864
#
# Cost at iteration 16 : 333.5606785218045
#
# Cost at iteration 17 : 333.4751911726136
#
# Cost at iteration 18 : 333.38750734169577
#
# Cost at iteration 19 : 333.297159003953
#
# Cost at iteration 20 : 333.20357573014786
#
# Cost at iteration 21 : 333.10589717654625
#
# Cost at iteration 22 : 333.0021694128727
#
# Cost at iteration 23 : 332.8888842819651
#
# Cost at iteration 24 : 332.76445959919425
#
# Cost at iteration 25 : 332.62814775645967
#
# Cost at iteration 26 : 332.4766589289745
#
# Cost at iteration 27 : 332.30543727669385
#
# Cost at iteration 28 : 332.1082490409232
#
# Cost at iteration 29 : 331.8764284735755
#
# Cost at iteration 30 : 331.59771770395463
#
# Cost at iteration 31 : 331.25443987239635
#
# Cost at iteration 32 : 330.82055197972153
#
# Cost at iteration 33 : 330.2567645958479
#
# Cost at iteration 34 : 329.5021993996839
#
# Cost at iteration 35 : 328.4596555292168
#
# Cost at iteration 36 : 326.9686201679875
#
# Cost at iteration 37 : 324.7538261721234
#
# Cost at iteration 38 : 321.32300963141597
#
# Cost at iteration 39 : 315.75517837317716
#
# Cost at iteration 40 : 306.2479249499817
#
# Cost at iteration 41 : 289.15187368414354
#
# Cost at iteration 42 : 257.16400269634073
#
# Cost at iteration 43 : 198.26335088488744
#
# Cost at iteration 44 : 111.21789011552268
#
# Cost at iteration 45 : 61.25684904780754
#
# Cost at iteration 46 : 60.22918877189882
#
# Cost at iteration 47 : 59.35177203562156
#
# Cost at iteration 48 : 58.52824019056956
#
# Cost at iteration 49 : 57.74349412590763
#
# Cost at iteration 50 : 56.98564470616558
#
# RMS error of the model=>  12.03623695041331

# %% [markdown]
# #### 2. Making predictions to the seeds dataset using the Neural network built from scratch

# %%
# Initialise the hyperparameters
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.05
layer_sizes=[7,6,4,3]

df =  pd.read_csv('seeds.csv')
n=df.shape[1]
m=df.shape[0]

x_train=np.array(df.iloc[:int(0.8*m),:n-1])
y_train=np.array(df.iloc[:int(0.8*m),-1])  
x_test=np.array(df.iloc[int(0.8*m):,:n-1])
y_test=np.array(df.iloc[int(0.8*m):,-1]) 
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)
y_predict = predict(x_test,params)

print(y_predict)
# Out:
# Cost at iteration 1 : 5.385114467445681
#
# Cost at iteration 2 : 5.382354525028408
#
# Cost at iteration 3 : 5.379596232706571
#
# Cost at iteration 4 : 5.3768395892651775
#
# Cost at iteration 5 : 5.374084596510653
#
# Cost at iteration 6 : 5.371331253435655
#
# Cost at iteration 7 : 5.36857955733868
#
# Cost at iteration 8 : 5.365829505167856
#
# Cost at iteration 9 : 5.363081094660069
#
# Cost at iteration 10 : 5.360334328247454
#
# Cost at iteration 11 : 5.357589204675126
#
# Cost at iteration 12 : 5.354845722604068
#
# Cost at iteration 13 : 5.352103882884311
#
# Cost at iteration 14 : 5.349363684818263
#
# Cost at iteration 15 : 5.346625127404142
#
# Cost at iteration 16 : 5.343888208550597
#
# Cost at iteration 17 : 5.341152927640914
#
# Cost at iteration 18 : 5.338419283257103
#
# Cost at iteration 19 : 5.33568727365674
#
# Cost at iteration 20 : 5.332956899160859
#
# Cost at iteration 21 : 5.330228154902862
#
# Cost at iteration 22 : 5.327501043349976
#
# Cost at iteration 23 : 5.324775564465555
#
# Cost at iteration 24 : 5.322051717253389
#
# Cost at iteration 25 : 5.319329500717896
#
# Cost at iteration 26 : 5.31660891386413
#
# Cost at iteration 27 : 5.313889955697767
#
# Cost at iteration 28 : 5.311172625225114
#
# Cost at iteration 29 : 5.3084569214531045
#
# Cost at iteration 30 : 5.305742843389302
#
# Cost at iteration 31 : 5.30303039004189
#
# Cost at iteration 32 : 5.300319560419684
#
# Cost at iteration 33 : 5.29761035353212
#
# Cost at iteration 34 : 5.294902768389263
#
# Cost at iteration 35 : 5.292196804001795
#
# Cost at iteration 36 : 5.289492459381033
#
# Cost at iteration 37 : 5.286789733538904
#
# Cost at iteration 38 : 5.284088625487966
#
# Cost at iteration 39 : 5.2813891342413966
#
# Cost at iteration 40 : 5.2786912588129935
#
# Cost at iteration 41 : 5.275994998217175
#
# Cost at iteration 42 : 5.273300351468984
#
# Cost at iteration 43 : 5.270607317584074
#
# Cost at iteration 44 : 5.267915895578726
#
# Cost at iteration 45 : 5.265226084469836
#
# Cost at iteration 46 : 5.262537882999103
#
# Cost at iteration 47 : 5.259851289730402
#
# Cost at iteration 48 : 5.257166304412468
#
# Cost at iteration 49 : 5.254482926064654
#
# Cost at iteration 50 : 5.25180115370693
#
# Cost at iteration 51 : 5.249120986359883
#
# Cost at iteration 52 : 5.246442423044709
#
# Cost at iteration 53 : 5.243765462783222
#
# Cost at iteration 54 : 5.241090104597852
#
# Cost at iteration 55 : 5.2384163475116345
#
# Cost at iteration 56 : 5.2357441905482265
#
# Cost at iteration 57 : 5.233073632731888
#
# Cost at iteration 58 : 5.230404673087499
#
# Cost at iteration 59 : 5.227737310640542
#
# Cost at iteration 60 : 5.2250715444171165
#
# Cost at iteration 61 : 5.222407373443928
#
# Cost at iteration 62 : 5.2197447967482935
#
# Cost at iteration 63 : 5.217083813358135
#
# Cost at iteration 64 : 5.21442442230199
#
# Cost at iteration 65 : 5.211766622608995
#
# Cost at iteration 66 : 5.209110413308898
#
# Cost at iteration 67 : 5.206455792860617
#
# Cost at iteration 68 : 5.203802760454487
#
# Cost at iteration 69 : 5.201151315533942
#
# Cost at iteration 70 : 5.198501456395859
#
# Cost at iteration 71 : 5.195853182535548
#
# Cost at iteration 72 : 5.193206493258901
#
# Cost at iteration 73 : 5.190561387599884
#
# Cost at iteration 74 : 5.187917864593058
#
# Cost at iteration 75 : 5.18527592327359
#
# Cost at iteration 76 : 5.182635562677249
#
# Cost at iteration 77 : 5.179996781840404
#
# Cost at iteration 78 : 5.177359579800025
#
# Cost at iteration 79 : 5.1747239555936835
#
# Cost at iteration 80 : 5.172089908259548
#
# Cost at iteration 81 : 5.169457436836392
#
# Cost at iteration 82 : 5.166826540363582
#
# Cost at iteration 83 : 5.16419721756808
#
# Cost at iteration 84 : 5.161569467152119
#
# Cost at iteration 85 : 5.158943288807932
#
# Cost at iteration 86 : 5.156318681577266
#
# Cost at iteration 87 : 5.153695644502465
#
# Cost at iteration 88 : 5.1510741766264685
#
# Cost at iteration 89 : 5.148454276992812
#
# Cost at iteration 90 : 5.145835944645624
#
# Cost at iteration 91 : 5.143219178629629
#
# Cost at iteration 92 : 5.14060397770721
#
# Cost at iteration 93 : 5.137990340534412
#
# Cost at iteration 94 : 5.135378266830231
#
# Cost at iteration 95 : 5.13276775560362
#
# Cost at iteration 96 : 5.130158805032375
#
# Cost at iteration 97 : 5.1275514150724595
#
# Cost at iteration 98 : 5.124945584772723
#
# Cost at iteration 99 : 5.122341313182603
#
# Cost at iteration 100 : 5.119738599352128
#
# Cost at iteration 101 : 5.117137442331915
#
# Cost at iteration 102 : 5.114537841173169
#
# Cost at iteration 103 : 5.111939794716458
#
# Cost at iteration 104 : 5.109343301423409
#
# Cost at iteration 105 : 5.106748361148589
#
# Cost at iteration 106 : 5.104154972945546
#
# Cost at iteration 107 : 5.101563135348351
#
# Cost at iteration 108 : 5.098972847478619
#
# Cost at iteration 109 : 5.096384108844423
#
# Cost at iteration 110 : 5.093796918501639
#
# Cost at iteration 111 : 5.091211275506727
#
# Cost at iteration 112 : 5.08862717891673
#
# Cost at iteration 113 : 5.086044626506685
#
# Cost at iteration 114 : 5.0834636169360765
#
# Cost at iteration 115 : 5.080884150943754
#
# Cost at iteration 116 : 5.078306227589057
#
# Cost at iteration 117 : 5.075729845292783
#
# Cost at iteration 118 : 5.073155003397694
#
# Cost at iteration 119 : 5.070581701321301
#
# Cost at iteration 120 : 5.068009937941547
#
# Cost at iteration 121 : 5.065439711725996
#
# Cost at iteration 122 : 5.0628710225154006
#
# Cost at iteration 123 : 5.060303869373136
#
# Cost at iteration 124 : 5.057738251255929
#
# Cost at iteration 125 : 5.05517416580706
#
# Cost at iteration 126 : 5.052611611819532
#
# Cost at iteration 127 : 5.050050589543703
#
# Cost at iteration 128 : 5.047491097944379
#
# Cost at iteration 129 : 5.04493313575553
#
# Cost at iteration 130 : 5.042376701785909
#
# Cost at iteration 131 : 5.039821796408761
#
# Cost at iteration 132 : 5.037268418692577
#
# Cost at iteration 133 : 5.034716567500653
#
# Cost at iteration 134 : 5.032166241383536
#
# Cost at iteration 135 : 5.029617439383201
#
# Cost at iteration 136 : 5.027070161076893
#
# Cost at iteration 137 : 5.024524405439925
#
# Cost at iteration 138 : 5.021980171421441
#
# Cost at iteration 139 : 5.0194374579734635
#
# Cost at iteration 140 : 5.0168962647534565
#
# Cost at iteration 141 : 5.014356590577076
#
# Cost at iteration 142 : 5.01181843393063
#
# Cost at iteration 143 : 5.009281794453806
#
# Cost at iteration 144 : 5.00674667150233
#
# Cost at iteration 145 : 5.004213064152059
#
# Cost at iteration 146 : 5.001680970110154
#
# Cost at iteration 147 : 4.9991503881639865
#
# Cost at iteration 148 : 4.996621318240165
#
# Cost at iteration 149 : 4.994093758232065
#
# Cost at iteration 150 : 4.991567708229438
#
# Cost at iteration 151 : 4.9890431682909435
#
# Cost at iteration 152 : 4.986520136515788
#
# Cost at iteration 153 : 4.983998611780413
#
# Cost at iteration 154 : 4.981478594149465
#
# Cost at iteration 155 : 4.978960082903918
#
# Cost at iteration 156 : 4.976443075763509
#
# Cost at iteration 157 : 4.973927572510212
#
# Cost at iteration 158 : 4.971413572530313
#
# Cost at iteration 159 : 4.968901074283546
#
# Cost at iteration 160 : 4.966390077236526
#
# Cost at iteration 161 : 4.963880581072612
#
# Cost at iteration 162 : 4.961372584877107
#
# Cost at iteration 163 : 4.958866087735875
#
# Cost at iteration 164 : 4.956361088735341
#
# Cost at iteration 165 : 4.953857586962485
#
# Cost at iteration 166 : 4.951355581504848
#
# Cost at iteration 167 : 4.9488550714505255
#
# Cost at iteration 168 : 4.946356055888175
#
# Cost at iteration 169 : 4.943858533907005
#
# Cost at iteration 170 : 4.941362504596785
#
# Cost at iteration 171 : 4.938867967047837
#
# Cost at iteration 172 : 4.936374920351038
#
# Cost at iteration 173 : 4.9338833635978245
#
# Cost at iteration 174 : 4.931393295880182
#
# Cost at iteration 175 : 4.92890471629065
#
# Cost at iteration 176 : 4.926417623922328
#
# Cost at iteration 177 : 4.923932017868861
#
# Cost at iteration 178 : 4.92144789684297
#
# Cost at iteration 179 : 4.918965260299055
#
# Cost at iteration 180 : 4.9164841073543055
#
# Cost at iteration 181 : 4.914004437104569
#
# Cost at iteration 182 : 4.91152624763116
#
# Cost at iteration 183 : 4.909049539006942
#
# Cost at iteration 184 : 4.906574309809149
#
# Cost at iteration 185 : 4.904100559265525
#
# Cost at iteration 186 : 4.901628286902851
#
# Cost at iteration 187 : 4.899157490962271
#
# Cost at iteration 188 : 4.896688170854838
#
# Cost at iteration 189 : 4.894220326226669
#
# Cost at iteration 190 : 4.891753955834816
#
# Cost at iteration 191 : 4.889289059045582
#
# Cost at iteration 192 : 4.886825635039554
#
# Cost at iteration 193 : 4.8843636825573435
#
# Cost at iteration 194 : 4.881903200413437
#
# Cost at iteration 195 : 4.879444188292579
#
# Cost at iteration 196 : 4.876986644072454
#
# Cost at iteration 197 : 4.874530567935066
#
# Cost at iteration 198 : 4.8720759590202345
#
# Cost at iteration 199 : 4.869622816615156
#
# Cost at iteration 200 : 4.867171139826002
#
# Cost at iteration 201 : 4.864720927759486
#
# Cost at iteration 202 : 4.862272178974012
#
# Cost at iteration 203 : 4.859824892675504
#
# Cost at iteration 204 : 4.857379067664353
#
# Cost at iteration 205 : 4.85493470363848
#
# Cost at iteration 206 : 4.852491799875271
#
# Cost at iteration 207 : 4.850050355484663
#
# Cost at iteration 208 : 4.847610369577132
#
# Cost at iteration 209 : 4.845171841263696
#
# Cost at iteration 210 : 4.842734769655907
#
# Cost at iteration 211 : 4.840299153096379
#
# Cost at iteration 212 : 4.837864990639223
#
# Cost at iteration 213 : 4.83543228220176
#
# Cost at iteration 214 : 4.833001026921506
#
# Cost at iteration 215 : 4.830571223912685
#
# Cost at iteration 216 : 4.828142872290055
#
# Cost at iteration 217 : 4.825715971168911
#
# Cost at iteration 218 : 4.823290519512517
#
# Cost at iteration 219 : 4.820866515737273
#
# Cost at iteration 220 : 4.818443959811684
#
# Cost at iteration 221 : 4.816022850853169
#
# Cost at iteration 222 : 4.813603187710402
#
# Cost at iteration 223 : 4.811184968695507
#
# Cost at iteration 224 : 4.808768193986899
#
# Cost at iteration 225 : 4.806352862719437
#
# Cost at iteration 226 : 4.803938974013188
#
# Cost at iteration 227 : 4.8015265260577005
#
# Cost at iteration 228 : 4.799115518808553
#
# Cost at iteration 229 : 4.796705951483015
#
# Cost at iteration 230 : 4.794297822949157
#
# Cost at iteration 231 : 4.791891132433381
#
# Cost at iteration 232 : 4.7894858792093
#
# Cost at iteration 233 : 4.787082061461678
#
# Cost at iteration 234 : 4.784679679234572
#
# Cost at iteration 235 : 4.782278731671075
#
# Cost at iteration 236 : 4.779879217896519
#
# Cost at iteration 237 : 4.777481137036762
#
# Cost at iteration 238 : 4.77508448821819
#
# Cost at iteration 239 : 4.772689270567711
#
# Cost at iteration 240 : 4.770295483212761
#
# Cost at iteration 241 : 4.767903125195044
#
# Cost at iteration 242 : 4.7655121951363055
#
# Cost at iteration 243 : 4.763122691157318
#
# Cost at iteration 244 : 4.760734613986887
#
# Cost at iteration 245 : 4.758347962724084
#
# Cost at iteration 246 : 4.755962735175268
#
# Cost at iteration 247 : 4.75357893121577
#
# Cost at iteration 248 : 4.751196550586008
#
# Cost at iteration 249 : 4.74881559241808
#
# Cost at iteration 250 : 4.746436055844608
#
# Cost at iteration 251 : 4.744057939998734
#
# Cost at iteration 252 : 4.741681244014116
#
# Cost at iteration 253 : 4.739305967024938
#
# Cost at iteration 254 : 4.7369321080770295
#
# Cost at iteration 255 : 4.7345596654288675
#
# Cost at iteration 256 : 4.732188639180665
#
# Cost at iteration 257 : 4.729819028468667
#
# Cost at iteration 258 : 4.7274508321009785
#
# Cost at iteration 259 : 4.725084049485022
#
# Cost at iteration 260 : 4.7227186798170315
#
# Cost at iteration 261 : 4.720354722235318
#
# Cost at iteration 262 : 4.717992175216454
#
# Cost at iteration 263 : 4.715631038191483
#
# Cost at iteration 264 : 4.713271310669659
#
# Cost at iteration 265 : 4.710912990860525
#
# Cost at iteration 266 : 4.708556077967834
#
# Cost at iteration 267 : 4.706200570819173
#
# Cost at iteration 268 : 4.703846468992033
#
# Cost at iteration 269 : 4.7014937723714665
#
# Cost at iteration 270 : 4.699142479342202
#
# Cost at iteration 271 : 4.696792589607183
#
# Cost at iteration 272 : 4.694444102507844
#
# Cost at iteration 273 : 4.692097017188596
#
# Cost at iteration 274 : 4.689751332794366
#
# Cost at iteration 275 : 4.687407048337902
#
# Cost at iteration 276 : 4.685064162840479
#
# Cost at iteration 277 : 4.682722675705812
#
# Cost at iteration 278 : 4.680382586080859
#
# Cost at iteration 279 : 4.678043892906769
#
# Cost at iteration 280 : 4.675706595313448
#
# Cost at iteration 281 : 4.67337069228574
#
# Cost at iteration 282 : 4.671036183360449
#
# Cost at iteration 283 : 4.668703067603552
#
# Cost at iteration 284 : 4.666371343590359
#
# Cost at iteration 285 : 4.664041010690967
#
# Cost at iteration 286 : 4.661712068494659
#
# Cost at iteration 287 : 4.659384515999839
#
# Cost at iteration 288 : 4.6570583510466985
#
# Cost at iteration 289 : 4.654733573343361
#
# Cost at iteration 290 : 4.652410182950523
#
# Cost at iteration 291 : 4.650088178408723
#
# Cost at iteration 292 : 4.647767558794234
#
# Cost at iteration 293 : 4.645448323951007
#
# Cost at iteration 294 : 4.6431304730340415
#
# Cost at iteration 295 : 4.640814005198836
#
# Cost at iteration 296 : 4.6384989196013935
#
# Cost at iteration 297 : 4.636185215398217
#
# Cost at iteration 298 : 4.633872891746311
#
# Cost at iteration 299 : 4.6315619472000416
#
# Cost at iteration 300 : 4.629252381202217
#
# Cost at iteration 301 : 4.626944193130696
#
# Cost at iteration 302 : 4.6246373813575525
#
# Cost at iteration 303 : 4.622331945789949
#
# Cost at iteration 304 : 4.620027884909977
#
# Cost at iteration 305 : 4.617725198470235
#
# Cost at iteration 306 : 4.61542388535084
#
# Cost at iteration 307 : 4.6131239438161575
#
# Cost at iteration 308 : 4.610825374424772
#
# Cost at iteration 309 : 4.608528176339122
#
# Cost at iteration 310 : 4.606232348722143
#
# Cost at iteration 311 : 4.603937890465815
#
# Cost at iteration 312 : 4.601644800839216
#
# Cost at iteration 313 : 4.599353078302816
#
# Cost at iteration 314 : 4.597062722890418
#
# Cost at iteration 315 : 4.59477373320517
#
# Cost at iteration 316 : 4.5924861081707204
#
# Cost at iteration 317 : 4.590199847756499
#
# Cost at iteration 318 : 4.587914951108172
#
# Cost at iteration 319 : 4.585631417017872
#
# Cost at iteration 320 : 4.5833492439289385
#
# Cost at iteration 321 : 4.58106843192317
#
# Cost at iteration 322 : 4.578788980370349
#
# Cost at iteration 323 : 4.576510888056755
#
# Cost at iteration 324 : 4.574234154539911
#
# Cost at iteration 325 : 4.571958778789751
#
# Cost at iteration 326 : 4.569684760014691
#
# Cost at iteration 327 : 4.567412097454093
#
# Cost at iteration 328 : 4.5651407900657786
#
# Cost at iteration 329 : 4.562870837330166
#
# Cost at iteration 330 : 4.560602238419972
#
# Cost at iteration 331 : 4.558334992508401
#
# Cost at iteration 332 : 4.556069098769147
#
# Cost at iteration 333 : 4.553804556376389
#
# Cost at iteration 334 : 4.551541364455634
#
# Cost at iteration 335 : 4.549279521119249
#
# Cost at iteration 336 : 4.5470190265869315
#
# Cost at iteration 337 : 4.544759880007277
#
# Cost at iteration 338 : 4.542502080350349
#
# Cost at iteration 339 : 4.540245627094394
#
# Cost at iteration 340 : 4.537990519416972
#
# Cost at iteration 341 : 4.535736756496129
#
# Cost at iteration 342 : 4.5334843371717035
#
# Cost at iteration 343 : 4.531233260875764
#
# Cost at iteration 344 : 4.528983526873223
#
# Cost at iteration 345 : 4.526735134344049
#
# Cost at iteration 346 : 4.524488081036506
#
# Cost at iteration 347 : 4.522242366801075
#
# Cost at iteration 348 : 4.519997991579741
#
# Cost at iteration 349 : 4.51775495455438
#
# Cost at iteration 350 : 4.515513254733536
#
# Cost at iteration 351 : 4.513272891216494
#
# Cost at iteration 352 : 4.511033863443699
#
# Cost at iteration 353 : 4.508796170598942
#
# Cost at iteration 354 : 4.506559811444603
#
# Cost at iteration 355 : 4.504324785264305
#
# Cost at iteration 356 : 4.502091091565874
#
# Cost at iteration 357 : 4.499858729193717
#
# Cost at iteration 358 : 4.4976276976315654
#
# Cost at iteration 359 : 4.495397996109581
#
# Cost at iteration 360 : 4.493169623466307
#
# Cost at iteration 361 : 4.490942579190659
#
# Cost at iteration 362 : 4.488716862517743
#
# Cost at iteration 363 : 4.486492472283217
#
# Cost at iteration 364 : 4.484269407972045
#
# Cost at iteration 365 : 4.482047668830415
#
# Cost at iteration 366 : 4.4798272540482875
#
# Cost at iteration 367 : 4.477608162635878
#
# Cost at iteration 368 : 4.475390393756451
#
# Cost at iteration 369 : 4.473173945912199
#
# Cost at iteration 370 : 4.470958819122485
#
# Cost at iteration 371 : 4.468745012647436
#
# Cost at iteration 372 : 4.466532525679831
#
# Cost at iteration 373 : 4.464321357412922
#
# Cost at iteration 374 : 4.462111507040433
#
# Cost at iteration 375 : 4.459902973756554
#
# Cost at iteration 376 : 4.457695756755946
#
# Cost at iteration 377 : 4.455489855233742
#
# Cost at iteration 378 : 4.453285268101522
#
# Cost at iteration 379 : 4.451081994762501
#
# Cost at iteration 380 : 4.448880034489864
#
# Cost at iteration 381 : 4.446679386480612
#
# Cost at iteration 382 : 4.444480049932211
#
# Cost at iteration 383 : 4.44228202388246
#
# Cost at iteration 384 : 4.440085306772562
#
# Cost at iteration 385 : 4.437889898392307
#
# Cost at iteration 386 : 4.43569579826559
#
# Cost at iteration 387 : 4.433503005592197
#
# Cost at iteration 388 : 4.431311519572376
#
# Cost at iteration 389 : 4.429121339406848
#
# Cost at iteration 390 : 4.4269324642967876
#
# Cost at iteration 391 : 4.424744893443838
#
# Cost at iteration 392 : 4.422558626050107
#
# Cost at iteration 393 : 4.420373661026929
#
# Cost at iteration 394 : 4.418189997780963
#
# Cost at iteration 395 : 4.416007635603057
#
# Cost at iteration 396 : 4.413826573697161
#
# Cost at iteration 397 : 4.411646811267693
#
# Cost at iteration 398 : 4.409468347287462
#
# Cost at iteration 399 : 4.407291181012771
#
# Cost at iteration 400 : 4.4051153118302295
#
# Cost at iteration 401 : 4.402940738946089
#
# Cost at iteration 402 : 4.4007674615670656
#
# Cost at iteration 403 : 4.398595478900329
#
# Cost at iteration 404 : 4.396424790153508
#
# Cost at iteration 405 : 4.3942553943846185
#
# Cost at iteration 406 : 4.392087290233579
#
# Cost at iteration 407 : 4.389920477345793
#
# Cost at iteration 408 : 4.387754955212201
#
# Cost at iteration 409 : 4.385590723042713
#
# Cost at iteration 410 : 4.383427780047692
#
# Cost at iteration 411 : 4.381266125064825
#
# Cost at iteration 412 : 4.3791057576444405
#
# Cost at iteration 413 : 4.376946677032055
#
# Cost at iteration 414 : 4.374788882439851
#
# Cost at iteration 415 : 4.372632373080465
#
# Cost at iteration 416 : 4.37047714816699
#
# Cost at iteration 417 : 4.368323206912971
#
# Cost at iteration 418 : 4.366170548532406
#
# Cost at iteration 419 : 4.364019172239746
#
# Cost at iteration 420 : 4.361869077249895
#
# Cost at iteration 421 : 4.359720262778209
#
# Cost at iteration 422 : 4.357572728040497
#
# Cost at iteration 423 : 4.355426472253014
#
# Cost at iteration 424 : 4.353281494632474
#
# Cost at iteration 425 : 4.351137794396035
#
# Cost at iteration 426 : 4.34899537046541
#
# Cost at iteration 427 : 4.346854222275982
#
# Cost at iteration 428 : 4.344714349124545
#
# Cost at iteration 429 : 4.342575750230056
#
# Cost at iteration 430 : 4.340438424811918
#
# Cost at iteration 431 : 4.338302372089984
#
# Cost at iteration 432 : 4.336167591284556
#
# Cost at iteration 433 : 4.334034081616379
#
# Cost at iteration 434 : 4.3319018423066495
#
# Cost at iteration 435 : 4.329770872577009
#
# Cost at iteration 436 : 4.327641171649545
#
# Cost at iteration 437 : 4.3255127387467915
#
# Cost at iteration 438 : 4.323385573091729
#
# Cost at iteration 439 : 4.321259673907779
#
# Cost at iteration 440 : 4.319135040418812
#
# Cost at iteration 441 : 4.317011671849142
#
# Cost at iteration 442 : 4.314889567423527
#
# Cost at iteration 443 : 4.3127687263671675
#
# Cost at iteration 444 : 4.310649146828822
#
# Cost at iteration 445 : 4.30853082885816
#
# Cost at iteration 446 : 4.30641377192672
#
# Cost at iteration 447 : 4.304297974868721
#
# Cost at iteration 448 : 4.302183437309461
#
# Cost at iteration 449 : 4.300070158476775
#
# Cost at iteration 450 : 4.297958137598943
#
# Cost at iteration 451 : 4.295847373904683
#
# Cost at iteration 452 : 4.293737866623155
#
# Cost at iteration 453 : 4.2916296149238
#
# Cost at iteration 454 : 4.289522617761349
#
# Cost at iteration 455 : 4.287416874701403
#
# Cost at iteration 456 : 4.285312384974876
#
# Cost at iteration 457 : 4.283209147813118
#
# Cost at iteration 458 : 4.281107162447916
#
# Cost at iteration 459 : 4.279006428111496
#
# Cost at iteration 460 : 4.276906944036521
#
# Cost at iteration 461 : 4.274808709456091
#
# Cost at iteration 462 : 4.272711723418628
#
# Cost at iteration 463 : 4.270615985095344
#
# Cost at iteration 464 : 4.268521493968136
#
# Cost at iteration 465 : 4.266428249271846
#
# Cost at iteration 466 : 4.264336250241743
#
# Cost at iteration 467 : 4.262245496113538
#
# Cost at iteration 468 : 4.2601559847572545
#
# Cost at iteration 469 : 4.258067716309065
#
# Cost at iteration 470 : 4.255980690469002
#
# Cost at iteration 471 : 4.253894906474488
#
# Cost at iteration 472 : 4.2518103635633775
#
# Cost at iteration 473 : 4.24972706097396
#
# Cost at iteration 474 : 4.247644997944953
#
# Cost at iteration 475 : 4.245564173715505
#
# Cost at iteration 476 : 4.2434845875252
#
# Cost at iteration 477 : 4.241406238427296
#
# Cost at iteration 478 : 4.239329125668848
#
# Cost at iteration 479 : 4.237253248670529
#
# Cost at iteration 480 : 4.235178606673635
#
# Cost at iteration 481 : 4.233105198919893
#
# Cost at iteration 482 : 4.231033024348472
#
# Cost at iteration 483 : 4.228962082446465
#
# Cost at iteration 484 : 4.226892372515021
#
# Cost at iteration 485 : 4.224823893797576
#
# Cost at iteration 486 : 4.222756645537993
#
# Cost at iteration 487 : 4.220690626443457
#
# Cost at iteration 488 : 4.218625835377341
#
# Cost at iteration 489 : 4.216562272499959
#
# Cost at iteration 490 : 4.2144999370568605
#
# Cost at iteration 491 : 4.212438828294021
#
# Cost at iteration 492 : 4.210378945457845
#
# Cost at iteration 493 : 4.208320287795155
#
# Cost at iteration 494 : 4.206262854553202
#
# Cost at iteration 495 : 4.20420664497966
#
# Cost at iteration 496 : 4.202151658322622
#
# Cost at iteration 497 : 4.200097893830608
#
# Cost at iteration 498 : 4.19804535075256
#
# Cost at iteration 499 : 4.195994028337841
#
# Cost at iteration 500 : 4.193943925836236
#
# Cost at iteration 501 : 4.191895042496173
#
# Cost at iteration 502 : 4.189847376102178
#
# Cost at iteration 503 : 4.187800927369802
#
# Cost at iteration 504 : 4.185755695550497
#
# Cost at iteration 505 : 4.183711679896133
#
# Cost at iteration 506 : 4.18166887924475
#
# Cost at iteration 507 : 4.179627292292569
#
# Cost at iteration 508 : 4.177586919260254
#
# Cost at iteration 509 : 4.175547759401337
#
# Cost at iteration 510 : 4.1735098119697644
#
# Cost at iteration 511 : 4.171473076219904
#
# Cost at iteration 512 : 4.169437551406538
#
# Cost at iteration 513 : 4.167403236784867
#
# Cost at iteration 514 : 4.1653701302845505
#
# Cost at iteration 515 : 4.163338232309177
#
# Cost at iteration 516 : 4.1613075422900705
#
# Cost at iteration 517 : 4.159278059484074
#
# Cost at iteration 518 : 4.157249783148452
#
# Cost at iteration 519 : 4.1552227125408745
#
# Cost at iteration 520 : 4.153196846919433
#
# Cost at iteration 521 : 4.151172185542625
#
# Cost at iteration 522 : 4.1491487276693695
#
# Cost at iteration 523 : 4.147126472558992
#
# Cost at iteration 524 : 4.145105418056202
#
# Cost at iteration 525 : 4.143085564761337
#
# Cost at iteration 526 : 4.141066912006268
#
# Cost at iteration 527 : 4.139049459051955
#
# Cost at iteration 528 : 4.137033203160313
#
# Cost at iteration 529 : 4.135018144398464
#
# Cost at iteration 530 : 4.133004283215084
#
# Cost at iteration 531 : 4.130991618872738
#
# Cost at iteration 532 : 4.128980150634397
#
# Cost at iteration 533 : 4.126969877763441
#
# Cost at iteration 534 : 4.124960799523661
#
# Cost at iteration 535 : 4.122952915179254
#
# Cost at iteration 536 : 4.1209462239948245
#
# Cost at iteration 537 : 4.118940725235384
#
# Cost at iteration 538 : 4.116936418166352
#
# Cost at iteration 539 : 4.114933302053553
#
# Cost at iteration 540 : 4.112931376163219
#
# Cost at iteration 541 : 4.110930639761987
#
# Cost at iteration 542 : 4.1089310921169
#
# Cost at iteration 543 : 4.106932732495403
#
# Cost at iteration 544 : 4.10493556016535
#
# Cost at iteration 545 : 4.102939574394993
#
# Cost at iteration 546 : 4.100944774452994
#
# Cost at iteration 547 : 4.098951159608417
#
# Cost at iteration 548 : 4.096958729130725
#
# Cost at iteration 549 : 4.094967480798567
#
# Cost at iteration 550 : 4.092977413850893
#
# Cost at iteration 551 : 4.090988529073524
#
# Cost at iteration 552 : 4.089000825737495
#
# Cost at iteration 553 : 4.087014303114249
#
# Cost at iteration 554 : 4.085028959629873
#
# Cost at iteration 555 : 4.083044794713836
#
# Cost at iteration 556 : 4.081061808323515
#
# Cost at iteration 557 : 4.079079999731933
#
# Cost at iteration 558 : 4.077099368212513
#
# Cost at iteration 559 : 4.075119913039074
#
# Cost at iteration 560 : 4.073141632299908
#
# Cost at iteration 561 : 4.071164526173619
#
# Cost at iteration 562 : 4.069188593565375
#
# Cost at iteration 563 : 4.0672138327004985
#
# Cost at iteration 564 : 4.065240243754595
#
# Cost at iteration 565 : 4.06326782679438
#
# Cost at iteration 566 : 4.061296581096401
#
# Cost at iteration 567 : 4.059326504813893
#
# Cost at iteration 568 : 4.057357597882867
#
# Cost at iteration 569 : 4.055389860097896
#
# Cost at iteration 570 : 4.053423290795437
#
# Cost at iteration 571 : 4.051457888848085
#
# Cost at iteration 572 : 4.049493652564505
#
# Cost at iteration 573 : 4.0475305824835255
#
# Cost at iteration 574 : 4.045568677125638
#
# Cost at iteration 575 : 4.043607935577616
#
# Cost at iteration 576 : 4.041648358068031
#
# Cost at iteration 577 : 4.0396899438777005
#
# Cost at iteration 578 : 4.03773269228784
#
# Cost at iteration 579 : 4.0357766025800474
#
# Cost at iteration 580 : 4.033821674036317
#
# Cost at iteration 581 : 4.031867906026267
#
# Cost at iteration 582 : 4.029915296972037
#
# Cost at iteration 583 : 4.027963845053888
#
# Cost at iteration 584 : 4.026013550982641
#
# Cost at iteration 585 : 4.024064414484615
#
# Cost at iteration 586 : 4.022116434844098
#
# Cost at iteration 587 : 4.0201696113457706
#
# Cost at iteration 588 : 4.018223943274695
#
# Cost at iteration 589 : 4.016279429916322
#
# Cost at iteration 590 : 4.01433607063909
#
# Cost at iteration 591 : 4.012393864753425
#
# Cost at iteration 592 : 4.010452811440704
#
# Cost at iteration 593 : 4.00851291009133
#
# Cost at iteration 594 : 4.006574160166915
#
# Cost at iteration 595 : 4.004636560690563
#
# Cost at iteration 596 : 4.002700110940678
#
# Cost at iteration 597 : 4.000764810039836
#
# Cost at iteration 598 : 3.9988306560514975
#
# Cost at iteration 599 : 3.996897649652326
#
# Cost at iteration 600 : 3.99496579013199
#
# Cost at iteration 601 : 3.99303507678054
#
# Cost at iteration 602 : 3.991105508888405
#
# Cost at iteration 603 : 3.9891770857463973
#
# Cost at iteration 604 : 3.9872498066457087
#
# Cost at iteration 605 : 3.9853236708779116
#
# Cost at iteration 606 : 3.9833986777349573
#
# Cost at iteration 607 : 3.9814748253406007
#
# Cost at iteration 608 : 3.9795521136934178
#
# Cost at iteration 609 : 3.9776305425448983
#
# Cost at iteration 610 : 3.975710111201285
#
# Cost at iteration 611 : 3.9737908191339124
#
# Cost at iteration 612 : 3.971872665448298
#
# Cost at iteration 613 : 3.9699556494390236
#
# Cost at iteration 614 : 3.968039770401046
#
# Cost at iteration 615 : 3.966125027629702
#
# Cost at iteration 616 : 3.9642114204207015
#
# Cost at iteration 617 : 3.9622989480701305
#
# Cost at iteration 618 : 3.9603876098744473
#
# Cost at iteration 619 : 3.9584774051304876
#
# Cost at iteration 620 : 3.956568333135462
#
# Cost at iteration 621 : 3.9546603933113014
#
# Cost at iteration 622 : 3.9527535849170916
#
# Cost at iteration 623 : 3.9508479071673137
#
# Cost at iteration 624 : 3.9489433593606726
#
# Cost at iteration 625 : 3.9470399407962438
#
# Cost at iteration 626 : 3.9451376507734754
#
# Cost at iteration 627 : 3.9432364885921873
#
# Cost at iteration 628 : 3.941336453664858
#
# Cost at iteration 629 : 3.9394375452821184
#
# Cost at iteration 630 : 3.937539762644189
#
# Cost at iteration 631 : 3.935643105052369
#
# Cost at iteration 632 : 3.933747571808334
#
# Cost at iteration 633 : 3.931853162267981
#
# Cost at iteration 634 : 3.929959875860541
#
# Cost at iteration 635 : 3.9280677117098985
#
# Cost at iteration 636 : 3.9261766691192026
#
# Cost at iteration 637 : 3.9242867473919687
#
# Cost at iteration 638 : 3.9223979458320803
#
# Cost at iteration 639 : 3.9205102634525826
#
# Cost at iteration 640 : 3.9186236984604577
#
# Cost at iteration 641 : 3.916738251544918
#
# Cost at iteration 642 : 3.9148539222061762
#
# Cost at iteration 643 : 3.91297070960499
#
# Cost at iteration 644 : 3.9110886129992877
#
# Cost at iteration 645 : 3.9092076317601623
#
# Cost at iteration 646 : 3.907327765304326
#
# Cost at iteration 647 : 3.9054490127661072
#
# Cost at iteration 648 : 3.903571373453024
#
# Cost at iteration 649 : 3.901694846797972
#
# Cost at iteration 650 : 3.8998194320945183
#
# Cost at iteration 651 : 3.897945128758133
#
# Cost at iteration 652 : 3.896071936068929
#
# Cost at iteration 653 : 3.8941998532472426
#
# Cost at iteration 654 : 3.89232887959205
#
# Cost at iteration 655 : 3.8904590133001795
#
# Cost at iteration 656 : 3.888590254121282
#
# Cost at iteration 657 : 3.8867226019536645
#
# Cost at iteration 658 : 3.88485605610844
#
# Cost at iteration 659 : 3.8829906159913268
#
# Cost at iteration 660 : 3.8811262811232465
#
# Cost at iteration 661 : 3.8792630506310717
#
# Cost at iteration 662 : 3.877400923713032
#
# Cost at iteration 663 : 3.8755398996820323
#
# Cost at iteration 664 : 3.873679977851333
#
# Cost at iteration 665 : 3.871821157534552
#
# Cost at iteration 666 : 3.869963438045658
#
# Cost at iteration 667 : 3.8681068186989807
#
# Cost at iteration 668 : 3.866251298809199
#
# Cost at iteration 669 : 3.8643968776913478
#
# Cost at iteration 670 : 3.8625435546608164
#
# Cost at iteration 671 : 3.860691328745051
#
# Cost at iteration 672 : 3.858840198108337
#
# Cost at iteration 673 : 3.856990163502317
#
# Cost at iteration 674 : 3.8551412242437646
#
# Cost at iteration 675 : 3.853293379649809
#
# Cost at iteration 676 : 3.8514466290379277
#
# Cost at iteration 677 : 3.8496009717259505
#
# Cost at iteration 678 : 3.847756407032058
#
# Cost at iteration 679 : 3.845912934296353
#
# Cost at iteration 680 : 3.8440705530516976
#
# Cost at iteration 681 : 3.8422292623835603
#
# Cost at iteration 682 : 3.84038906161152
#
# Cost at iteration 683 : 3.838549950055504
#
# Cost at iteration 684 : 3.8367119270357866
#
# Cost at iteration 685 : 3.8348749916055196
#
# Cost at iteration 686 : 3.8330391420069594
#
# Cost at iteration 687 : 3.831204379056803
#
# Cost at iteration 688 : 3.8293707019244305
#
# Cost at iteration 689 : 3.8275381087284184
#
# Cost at iteration 690 : 3.8257065976768345
#
# Cost at iteration 691 : 3.8238761703998336
#
# Cost at iteration 692 : 3.8220468263432874
#
# Cost at iteration 693 : 3.8202185648697897
#
# Cost at iteration 694 : 3.818391385219812
#
# Cost at iteration 695 : 3.8165652868564135
#
# Cost at iteration 696 : 3.814740268889871
#
# Cost at iteration 697 : 3.8129163306448817
#
# Cost at iteration 698 : 3.8110934714464846
#
# Cost at iteration 699 : 3.809271690620061
#
# Cost at iteration 700 : 3.807450987491331
#
# Cost at iteration 701 : 3.805631361386356
#
# Cost at iteration 702 : 3.803812811631536
#
# Cost at iteration 703 : 3.8019953375536115
#
# Cost at iteration 704 : 3.800178938479662
#
# Cost at iteration 705 : 3.7983636137371004
#
# Cost at iteration 706 : 3.7965493626536864
#
# Cost at iteration 707 : 3.794736184617525
#
# Cost at iteration 708 : 3.7929240791390186
#
# Cost at iteration 709 : 3.7911130453069632
#
# Cost at iteration 710 : 3.789303082450464
#
# Cost at iteration 711 : 3.787494189898964
#
# Cost at iteration 712 : 3.78568636698224
#
# Cost at iteration 713 : 3.7838796132997916
#
# Cost at iteration 714 : 3.7820739279673323
#
# Cost at iteration 715 : 3.7802693102631286
#
# Cost at iteration 716 : 3.7784657595182973
#
# Cost at iteration 717 : 3.776663275064292
#
# Cost at iteration 718 : 3.774861856232894
#
# Cost at iteration 719 : 3.7730615023562235
#
# Cost at iteration 720 : 3.7712622127667266
#
# Cost at iteration 721 : 3.769463986797183
#
# Cost at iteration 722 : 3.7676668238368194
#
# Cost at iteration 723 : 3.765870723628067
#
# Cost at iteration 724 : 3.764075685227628
#
# Cost at iteration 725 : 3.762281707786055
#
# Cost at iteration 726 : 3.760488790637785
#
# Cost at iteration 727 : 3.758696933117586
#
# Cost at iteration 728 : 3.7569061345605537
#
# Cost at iteration 729 : 3.7551163943584753
#
# Cost at iteration 730 : 3.7533277118116977
#
# Cost at iteration 731 : 3.751540086235716
#
# Cost at iteration 732 : 3.7497535170050758
#
# Cost at iteration 733 : 3.747968003454454
#
# Cost at iteration 734 : 3.7461835448851826
#
# Cost at iteration 735 : 3.7444001406346406
#
# Cost at iteration 736 : 3.742617790040535
#
# Cost at iteration 737 : 3.7408364924408954
#
# Cost at iteration 738 : 3.7390562475198106
#
# Cost at iteration 739 : 3.737277054283509
#
# Cost at iteration 740 : 3.735498912075546
#
# Cost at iteration 741 : 3.733721820281243
#
# Cost at iteration 742 : 3.7319457781790635
#
# Cost at iteration 743 : 3.7301707851089767
#
# Cost at iteration 744 : 3.728396840411273
#
# Cost at iteration 745 : 3.72662394353787
#
# Cost at iteration 746 : 3.7248520939488423
#
# Cost at iteration 747 : 3.723081290846473
#
# Cost at iteration 748 : 3.7213115337583287
#
# Cost at iteration 749 : 3.719542821753276
#
# Cost at iteration 750 : 3.717775154173531
#
# Cost at iteration 751 : 3.7160085303616297
#
# Cost at iteration 752 : 3.7142429496604237
#
# Cost at iteration 753 : 3.7124784114130818
#
# Cost at iteration 754 : 3.7107149149630896
#
# Cost at iteration 755 : 3.708952459654249
#
# Cost at iteration 756 : 3.707191044830676
#
# Cost at iteration 757 : 3.705430669836803
#
# Cost at iteration 758 : 3.7036713340173777
#
# Cost at iteration 759 : 3.701913036717459
#
# Cost at iteration 760 : 3.700155777282423
#
# Cost at iteration 761 : 3.6983995550579585
#
# Cost at iteration 762 : 3.696644369390063
#
# Cost at iteration 763 : 3.6948902196250515
#
# Cost at iteration 764 : 3.6931371051311856
#
# Cost at iteration 765 : 3.691385025301421
#
# Cost at iteration 766 : 3.6896339794157575
#
# Cost at iteration 767 : 3.687883966821752
#
# Cost at iteration 768 : 3.686134986955903
#
# Cost at iteration 769 : 3.68438703907871
#
# Cost at iteration 770 : 3.682640122538114
#
# Cost at iteration 771 : 3.680894236682908
#
# Cost at iteration 772 : 3.679149380862194
#
# Cost at iteration 773 : 3.6774055545005258
#
# Cost at iteration 774 : 3.6756627568961875
#
# Cost at iteration 775 : 3.673920987672219
#
# Cost at iteration 776 : 3.6721802460420836
#
# Cost at iteration 777 : 3.670440531199385
#
# Cost at iteration 778 : 3.668701842558601
#
# Cost at iteration 779 : 3.666964179445656
#
# Cost at iteration 780 : 3.665227541264849
#
# Cost at iteration 781 : 3.663491927283566
#
# Cost at iteration 782 : 3.6617573368483636
#
# Cost at iteration 783 : 3.6600237693117057
#
# Cost at iteration 784 : 3.6582912240263576
#
# Cost at iteration 785 : 3.6565597003453867
#
# Cost at iteration 786 : 3.6548291976221603
#
# Cost at iteration 787 : 3.6530997152103493
#
# Cost at iteration 788 : 3.651371252463921
#
# Cost at iteration 789 : 3.649643808737149
#
# Cost at iteration 790 : 3.6479173833845966
#
# Cost at iteration 791 : 3.6461919757611363
#
# Cost at iteration 792 : 3.6444675853364696
#
# Cost at iteration 793 : 3.6427442115803896
#
# Cost at iteration 794 : 3.641021853831503
#
# Cost at iteration 795 : 3.639300511492062
#
# Cost at iteration 796 : 3.6375801837201043
#
# Cost at iteration 797 : 3.6358608699647332
#
# Cost at iteration 798 : 3.6341425696210465
#
# Cost at iteration 799 : 3.6324252819172096
#
# Cost at iteration 800 : 3.6307090062031224
#
# Cost at iteration 801 : 3.6289937418464
#
# Cost at iteration 802 : 3.6272794882080697
#
# Cost at iteration 803 : 3.625566244631432
#
# Cost at iteration 804 : 3.623854010431226
#
# Cost at iteration 805 : 3.622142784966458
#
# Cost at iteration 806 : 3.620432567596427
#
# Cost at iteration 807 : 3.618723357773425
#
# Cost at iteration 808 : 3.617015154845632
#
# Cost at iteration 809 : 3.615307958133413
#
# Cost at iteration 810 : 3.613601766956938
#
# Cost at iteration 811 : 3.611896580745822
#
# Cost at iteration 812 : 3.6101923988872966
#
# Cost at iteration 813 : 3.6084892208810557
#
# Cost at iteration 814 : 3.6067870458867173
#
# Cost at iteration 815 : 3.605085873315502
#
# Cost at iteration 816 : 3.603385702451348
#
# Cost at iteration 817 : 3.6016865326567298
#
# Cost at iteration 818 : 3.5999883632944094
#
# Cost at iteration 819 : 3.598291193727432
#
# Cost at iteration 820 : 3.5965950233370165
#
# Cost at iteration 821 : 3.594899851820062
#
# Cost at iteration 822 : 3.59320567831569
#
# Cost at iteration 823 : 3.591512502311119
#
# Cost at iteration 824 : 3.589820323248677
#
# Cost at iteration 825 : 3.588129140171007
#
# Cost at iteration 826 : 3.586438952443143
#
# Cost at iteration 827 : 3.5847497594303985
#
# Cost at iteration 828 : 3.5830615605476592
#
# Cost at iteration 829 : 3.581374355414631
#
# Cost at iteration 830 : 3.5796881432775907
#
# Cost at iteration 831 : 3.5780029235104656
#
# Cost at iteration 832 : 3.5763186955828217
#
# Cost at iteration 833 : 3.574635458807943
#
# Cost at iteration 834 : 3.5729532124605585
#
# Cost at iteration 835 : 3.5712719560722292
#
# Cost at iteration 836 : 3.5695916889827632
#
# Cost at iteration 837 : 3.5679124103747837
#
# Cost at iteration 838 : 3.5662341201598413
#
# Cost at iteration 839 : 3.5645568174060833
#
# Cost at iteration 840 : 3.562880501400503
#
# Cost at iteration 841 : 3.5612051715327553
#
# Cost at iteration 842 : 3.5595308273475412
#
# Cost at iteration 843 : 3.5578574677797974
#
# Cost at iteration 844 : 3.5561850921995584
#
# Cost at iteration 845 : 3.5545137000355043
#
# Cost at iteration 846 : 3.5528432907913445
#
# Cost at iteration 847 : 3.5511738636496317
#
# Cost at iteration 848 : 3.5495054179792658
#
# Cost at iteration 849 : 3.547837953151635
#
# Cost at iteration 850 : 3.54617146873301
#
# Cost at iteration 851 : 3.5445059639442107
#
# Cost at iteration 852 : 3.5428414381148463
#
# Cost at iteration 853 : 3.5411778912338066
#
# Cost at iteration 854 : 3.539515322287983
#
# Cost at iteration 855 : 3.5378537304240036
#
# Cost at iteration 856 : 3.5361931151213084
#
# Cost at iteration 857 : 3.534533476195618
#
# Cost at iteration 858 : 3.5328748125351526
#
# Cost at iteration 859 : 3.531217123555258
#
# Cost at iteration 860 : 3.5295604086466046
#
# Cost at iteration 861 : 3.527904667188567
#
# Cost at iteration 862 : 3.5262498989109163
#
# Cost at iteration 863 : 3.5245961028911563
#
# Cost at iteration 864 : 3.5229432785735386
#
# Cost at iteration 865 : 3.52129142509119
#
# Cost at iteration 866 : 3.5196405423413735
#
# Cost at iteration 867 : 3.5179906293835024
#
# Cost at iteration 868 : 3.516341685393073
#
# Cost at iteration 869 : 3.514693710016119
#
# Cost at iteration 870 : 3.5130467024750502
#
# Cost at iteration 871 : 3.5114006627750656
#
# Cost at iteration 872 : 3.509755589594573
#
# Cost at iteration 873 : 3.5081114822734154
#
# Cost at iteration 874 : 3.506468340284495
#
# Cost at iteration 875 : 3.504826163080924
#
# Cost at iteration 876 : 3.503184950842074
#
# Cost at iteration 877 : 3.5015447024254165
#
# Cost at iteration 878 : 3.499905417005951
#
# Cost at iteration 879 : 3.4982670937767546
#
# Cost at iteration 880 : 3.496629732337326
#
# Cost at iteration 881 : 3.494993332143365
#
# Cost at iteration 882 : 3.493357892334811
#
# Cost at iteration 883 : 3.4917234122717673
#
# Cost at iteration 884 : 3.490089891327153
#
# Cost at iteration 885 : 3.48845732897743
#
# Cost at iteration 886 : 3.4868257244892535
#
# Cost at iteration 887 : 3.4851950771885862
#
# Cost at iteration 888 : 3.4835653868975323
#
# Cost at iteration 889 : 3.4819366526734945
#
# Cost at iteration 890 : 3.4803088737848005
#
# Cost at iteration 891 : 3.4786820496136994
#
# Cost at iteration 892 : 3.477056179542679
#
# Cost at iteration 893 : 3.4754312631496096
#
# Cost at iteration 894 : 3.47380730027754
#
# Cost at iteration 895 : 3.472184289658692
#
# Cost at iteration 896 : 3.4705622306765362
#
# Cost at iteration 897 : 3.4689411227147873
#
# Cost at iteration 898 : 3.467320965157401
#
# Cost at iteration 899 : 3.465701757707344
#
# Cost at iteration 900 : 3.4640834995171623
#
# Cost at iteration 901 : 3.4624661901654603
#
# Cost at iteration 902 : 3.460849829347248
#
# Cost at iteration 903 : 3.459234415863019
#
# Cost at iteration 904 : 3.4576199498484326
#
# Cost at iteration 905 : 3.456006430959363
#
# Cost at iteration 906 : 3.454393858362213
#
# Cost at iteration 907 : 3.4527822308068092
#
# Cost at iteration 908 : 3.4511715486786105
#
# Cost at iteration 909 : 3.4495618107531905
#
# Cost at iteration 910 : 3.44795301614779
#
# Cost at iteration 911 : 3.446345164293332
#
# Cost at iteration 912 : 3.4447382548833576
#
# Cost at iteration 913 : 3.443132287460965
#
# Cost at iteration 914 : 3.441527261039394
#
# Cost at iteration 915 : 3.4399231746247425
#
# Cost at iteration 916 : 3.438320028023696
#
# Cost at iteration 917 : 3.4367178203687705
#
# Cost at iteration 918 : 3.4351165508888357
#
# Cost at iteration 919 : 3.4335162192563846
#
# Cost at iteration 920 : 3.431916824810087
#
# Cost at iteration 921 : 3.430318367199912
#
# Cost at iteration 922 : 3.4287208462414953
#
# Cost at iteration 923 : 3.4271242606830845
#
# Cost at iteration 924 : 3.425528610453573
#
# Cost at iteration 925 : 3.4239338941404758
#
# Cost at iteration 926 : 3.4223401112191394
#
# Cost at iteration 927 : 3.420747261833582
#
# Cost at iteration 928 : 3.4191553452262577
#
# Cost at iteration 929 : 3.417564360774961
#
# Cost at iteration 930 : 3.4159743072059205
#
# Cost at iteration 931 : 3.4143851841395354
#
# Cost at iteration 932 : 3.412796990967552
#
# Cost at iteration 933 : 3.4112097268556987
#
# Cost at iteration 934 : 3.40962339119632
#
# Cost at iteration 935 : 3.408037983381983
#
# Cost at iteration 936 : 3.406453503238656
#
# Cost at iteration 937 : 3.4048699497670545
#
# Cost at iteration 938 : 3.4032873227838696
#
# Cost at iteration 939 : 3.401705621416346
#
# Cost at iteration 940 : 3.400124845169147
#
# Cost at iteration 941 : 3.3985449931336764
#
# Cost at iteration 942 : 3.39696606470402
#
# Cost at iteration 943 : 3.395388059274477
#
# Cost at iteration 944 : 3.393810976239559
#
# Cost at iteration 945 : 3.3922348149939903
#
# Cost at iteration 946 : 3.3906595749327066
#
# Cost at iteration 947 : 3.3890852558486406
#
# Cost at iteration 948 : 3.38751185716844
#
# Cost at iteration 949 : 3.3859393780255145
#
# Cost at iteration 950 : 3.384367817653307
#
# Cost at iteration 951 : 3.382797175447804
#
# Cost at iteration 952 : 3.381227450879547
#
# Cost at iteration 953 : 3.379658643676715
#
# Cost at iteration 954 : 3.3780907530865467
#
# Cost at iteration 955 : 3.376523778518655
#
# Cost at iteration 956 : 3.3749577191051223
#
# Cost at iteration 957 : 3.373392574243177
#
# Cost at iteration 958 : 3.371828343330247
#
# Cost at iteration 959 : 3.3702650257639646
#
# Cost at iteration 960 : 3.368702620942162
#
# Cost at iteration 961 : 3.3671411282628743
#
# Cost at iteration 962 : 3.365580547124336
#
# Cost at iteration 963 : 3.364020876924981
#
# Cost at iteration 964 : 3.362462117174034
#
# Cost at iteration 965 : 3.3609042675905187
#
# Cost at iteration 966 : 3.3593473271451386
#
# Cost at iteration 967 : 3.357791295237125
#
# Cost at iteration 968 : 3.3562361712658997
#
# Cost at iteration 969 : 3.3546819546310815
#
# Cost at iteration 970 : 3.353128644732485
#
# Cost at iteration 971 : 3.351576240970115
#
# Cost at iteration 972 : 3.350024742744174
#
# Cost at iteration 973 : 3.3484741494550527
#
# Cost at iteration 974 : 3.346924460503335
#
# Cost at iteration 975 : 3.345375675289796
#
# Cost at iteration 976 : 3.3438277932153984
#
# Cost at iteration 977 : 3.3422808136812976
#
# Cost at iteration 978 : 3.3407347360888364
#
# Cost at iteration 979 : 3.3391895598395434
#
# Cost at iteration 980 : 3.3376452843351383
#
# Cost at iteration 981 : 3.3361019089775215
#
# Cost at iteration 982 : 3.334559433168784
#
# Cost at iteration 983 : 3.3330178563112
#
# Cost at iteration 984 : 3.3314771778072276
#
# Cost at iteration 985 : 3.3299373970595063
#
# Cost at iteration 986 : 3.328398513470862
#
# Cost at iteration 987 : 3.3268605264443
#
# Cost at iteration 988 : 3.325323435383008
#
# Cost at iteration 989 : 3.323787239690351
#
# Cost at iteration 990 : 3.322251938769876
#
# Cost at iteration 991 : 3.3207175320253093
#
# Cost at iteration 992 : 3.3191840188605544
#
# Cost at iteration 993 : 3.317651398679691
#
# Cost at iteration 994 : 3.316119670886976
#
# Cost at iteration 995 : 3.314588834886842
#
# Cost at iteration 996 : 3.313058890083898
#
# Cost at iteration 997 : 3.311529835882924
#
# Cost at iteration 998 : 3.3100016716888754
#
# Cost at iteration 999 : 3.308474396906878
#
# Cost at iteration 1000 : 3.3069480109422336
#
# [[0.4516376  0.45919791 0.46023283]
#  [0.45162122 0.45919213 0.46022737]
#  [0.45164693 0.45919139 0.46023537]
#  [0.45166985 0.45920269 0.46024503]
#  [0.45162988 0.4591925  0.4602307 ]
#  [0.45165061 0.45919812 0.46023778]
#  [0.45162202 0.45918554 0.46022621]
#  [0.45160262 0.45917344 0.4602213 ]
#  [0.45164118 0.45919432 0.46023427]
#  [0.45160598 0.45917714 0.46022153]
#  [0.45165693 0.45919989 0.46024043]
#  [0.4516621  0.45922632 0.4602429 ]
#  [0.45164201 0.45919524 0.46023563]
#  [0.45170051 0.45922918 0.46025743]
#  [0.4516861  0.45922214 0.46025164]
#  [0.45165678 0.45920296 0.46024085]
#  [0.45174328 0.45924923 0.46027202]
#  [0.45165234 0.45920898 0.46023779]
#  [0.45167447 0.45921775 0.4602456 ]
#  [0.45160898 0.45918128 0.46022291]
#  [0.45165514 0.45918921 0.46024   ]
#  [0.45159109 0.45916472 0.46021749]
#  [0.45162034 0.45918126 0.46022687]
#  [0.45162427 0.45919051 0.46022924]
#  [0.45165056 0.45920724 0.46023973]
#  [0.45161329 0.45918116 0.46022379]
#  [0.451675   0.45921909 0.46024807]
#  [0.45171534 0.4592369  0.46026378]
#  [0.45172266 0.45923853 0.46026593]
#  [0.45174696 0.45925708 0.46027522]
#  [0.4517003  0.45923967 0.46025666]
#  [0.45169105 0.45923303 0.46025573]
#  [0.45170261 0.45922788 0.46025783]
#  [0.45167927 0.45922853 0.46025167]
#  [0.45161671 0.45918475 0.46022707]
#  [0.45174298 0.45923396 0.46027315]
#  [0.4513328  0.45905141 0.46010734]
#  [0.45167028 0.45921786 0.46024715]
#  [0.45162733 0.45919084 0.46023006]
#  [0.45177066 0.45925071 0.46028344]
#  [0.45165476 0.45921061 0.46024028]
#  [0.45169845 0.4592245  0.4602565 ]]
