# %% [markdown]
# ## Data Science Lab Assignment - 8
# ##### Name: Boganadham Venkata Sai Manoj
# ##### Section: A
# ##### Roll no: 197121
#
# #### Implementing Artificial Neural Network from scratch

# %% [markdown]
# -----------------------------------------
# ##### First we need to import required libraries

# %%
# Importing the required libraries
#importing libraries and functions
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# -------------------------------------------------------------
# From here, we will start building our neural network.
# We will create helper functions which can work as building blocks of the model

# %% [markdown]
# ##### Defining the activation functions

# %%
def ReLU(z):
    # ReLU, on input x, returns 0 if x is non positive, and x itself if x is positive
    a = np.maximum(0, z)
    return a

# %% [markdown]
# ##### We also need to initialise the parameters of each of the layers

# %%
def initParams(layer_sizes):
    # Create a dictionary that will store parameters associated with its names (like w1, b1, etc.)
    params = {}

    # Creating the parameters for each layer
    for i in range(1, len(layer_sizes)):
        params['W' + str(i)] = np.random.randn(layer_sizes[i], layer_sizes[i-1])*0.01
        params['B' + str(i)] = np.random.randn(layer_sizes[i],1)*0.01
    return params

# %% [markdown]
# #### Forward Propagation

# %%
def frwdProp(X_train, parameters):
    layers = len(parameters)//2
    vals = {}
    # Calculating the activations layer by layer
    for i in range(1, layers+1):
        # First hidden layer
        if i==1:
            vals['Z' + str(i)] = np.dot(parameters['W' + str(i)], X_train) + parameters['B' + str(i)]
            vals['A' + str(i)] = ReLU(vals['Z' + str(i)])
        else:
            vals['Z' + str(i)] = np.dot(parameters['W' + str(i)], vals['A' + str(i-1)]) + parameters['B' + str(i)]
            if i==layers:
                vals['A' + str(i)] = vals['Z' + str(i)]
            else:
                vals['A' + str(i)] = ReLU(vals['Z' + str(i)])
    return vals

# %% [markdown]
# #### Computing the cost

# %%
def getCost(vals, Y_train):
    layers = len(vals)//2
    Y_pred = vals['A' + str(layers)]
    cost = 1/(2*len(Y_train)) * np.sum(np.square(Y_pred - Y_train))
    return cost

# %% [markdown]
# #### Backward Propagation

# %%
def backProp(parameters, vals, X_train, Y_train):
    layers = len(parameters)//2
    m = len(Y_train)
    grads = {}
    for i in range(layers,0,-1):
        # Calculating the gradients for the last layer
        if i==layers:
            dA = 1/m * (vals['A' + str(i)] - Y_train)
            dZ = dA
        # Calculating the gradients for the hidden layers
        else:
            dA = np.dot(parameters['W' + str(i+1)].T, dZ)
            dZ = np.multiply(dA, np.where(vals['A' + str(i)]>=0, 1, 0))
        # Calculating the gradients for the parameters
        if i==1:
            grads['W' + str(i)] = 1/m * np.dot(dZ, X_train.T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
        else:
            grads['W' + str(i)] = 1/m * np.dot(dZ,vals['A' + str(i-1)].T)
            grads['B' + str(i)] = 1/m * np.sum(dZ, axis=1, keepdims=True)
    return grads

# %% [markdown]
# #### Updating the parameters

# %%
def updParams(params, gradients, alpha):
    layers = len(params)//2
    params_updated = {}
    # Updating the parameters in layer by layer
    for i in range(1,layers+1):
        params_updated['W' + str(i)] = params['W' + str(i)] - alpha * gradients['W' + str(i)]
        params_updated['B' + str(i)] = params['B' + str(i)] - alpha * gradients['B' + str(i)]
    return params_updated

# %% [markdown]
# #### Creating the model

# %%
def model(X_train, Y_train, layer_sizes, num_iters, learning_rate):
    params = initParams(layer_sizes)
    for i in range(num_iters):
        values = frwdProp(X_train.T, params)
        cost = getCost(values, Y_train.T)
        grads = backProp(params, values,X_train.T, Y_train.T)
        params = updParams(params, grads, learning_rate)
        print('Cost at iteration ' + str(i+1) + ' = ' + str(cost) + '\n')
    return params

# %% [markdown]
# #### Accuracy calculation (using mean squared error)

# %%
def compute_accuracy(X_train, X_test, Y_train, Y_test, params):
    # Calculating the predictions
    trainVals = frwdProp(X_train.T, params)
    testVals = frwdProp(X_test.T, params)
    # Calculating the accuracy of the model
    trainAcc = np.sqrt(mean_squared_error(Y_train, trainVals['A' + str(len(layer_sizes)-1)].T))
    testAcc = np.sqrt(mean_squared_error(Y_test, testVals['A' + str(len(layer_sizes)-1)].T))
    return trainAcc, testAcc

# %% [markdown]
# #### Making predictions

# %%
def predict(X, params):
    # Making predictions using forward propagation
    vals = frwdProp(X.T, params)
    preds = vals['A' + str(len(vals)//2)].T
    return preds

# %% [markdown]
# --------------------------------------------------------------------------------------------
# #### **1. Making predictions to the boston housing dataset using the Neural network built from scratch**

# %%
# Initialising hyper parameters
layer_sizes = [13, 10, 5, 1]                                                       #set layer sizes, do not change the size of the first and last layer 
num_iters = 100                                                                 #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.05

# %% [markdown]
# Import the dataset and train the model

# %%
boston_dataset =  pd.read_csv('boston.csv')

n=boston_dataset.shape[1]
m=boston_dataset.shape[0]

# Splitting the dataset into the Training set and Test set
x_train=np.array(boston_dataset.iloc[:int(0.8*m),:n-1])
y_train=np.array(boston_dataset.iloc[:int(0.8*m),-1])  
x_test=np.array(boston_dataset.iloc[int(0.8*m):,:n-1])
y_test=np.array(boston_dataset.iloc[int(0.8*m):,-1])

# Creating the model and training it
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)

# Predicting the data
y_predict = predict(x_test,params)

# calculating the accuracy of the model using the Root Mean Squared Error
import math
error = math.sqrt(np.mean((y_test - y_predict)**2))

print("Root Mean Squared error of the model: ", error)
# Out:
# Cost at iteration 1 = 335.05775066067906
#
# Cost at iteration 2 = 334.983427783438
#
# Cost at iteration 3 = 334.9086853606264
#
# Cost at iteration 4 = 334.83370631342547
#
# Cost at iteration 5 = 334.75852404468225
#
# Cost at iteration 6 = 334.6830234183852
#
# Cost at iteration 7 = 334.6072866360732
#
# Cost at iteration 8 = 334.5313435295578
#
# Cost at iteration 9 = 334.45491927373735
#
# Cost at iteration 10 = 334.37800091906917
#
# Cost at iteration 11 = 334.30060254319386
#
# Cost at iteration 12 = 334.2226990719891
#
# Cost at iteration 13 = 334.14421908227763
#
# Cost at iteration 14 = 334.06511161432184
#
# Cost at iteration 15 = 333.98529672552235
#
# Cost at iteration 16 = 333.90465515291123
#
# Cost at iteration 17 = 333.823055310305
#
# Cost at iteration 18 = 333.74033155236657
#
# Cost at iteration 19 = 333.6562825565041
#
# Cost at iteration 20 = 333.57065320087065
#
# Cost at iteration 21 = 333.4830592781778
#
# Cost at iteration 22 = 333.39309612732706
#
# Cost at iteration 23 = 333.30042958227375
#
# Cost at iteration 24 = 333.2044669804198
#
# Cost at iteration 25 = 333.104243483389
#
# Cost at iteration 26 = 332.9987704617901
#
# Cost at iteration 27 = 332.88648533417296
#
# Cost at iteration 28 = 332.7665126605993
#
# Cost at iteration 29 = 332.63731685621457
#
# Cost at iteration 30 = 332.4965754679787
#
# Cost at iteration 31 = 332.34117971162215
#
# Cost at iteration 32 = 332.1669637394546
#
# Cost at iteration 33 = 331.9682877964016
#
# Cost at iteration 34 = 331.73743098640216
#
# Cost at iteration 35 = 331.4635659506282
#
# Cost at iteration 36 = 331.1312625035762
#
# Cost at iteration 37 = 330.718074127569
#
# Cost at iteration 38 = 330.1905923349418
#
# Cost at iteration 39 = 329.4978072915365
#
# Cost at iteration 40 = 328.559573998377
#
# Cost at iteration 41 = 327.24586044074385
#
# Cost at iteration 42 = 325.3379520350198
#
# Cost at iteration 43 = 322.45288541810595
#
# Cost at iteration 44 = 317.8899690801727
#
# Cost at iteration 45 = 310.30720965298525
#
# Cost at iteration 46 = 297.0272586516992
#
# Cost at iteration 47 = 272.6266839955583
#
# Cost at iteration 48 = 226.9924345920466
#
# Cost at iteration 49 = 149.68718624560583
#
# Cost at iteration 50 = 71.3094301903459
#
# Cost at iteration 51 = 60.776515226516985
#
# Cost at iteration 52 = 59.36850404734283
#
# Cost at iteration 53 = 58.187895295735835
#
# Cost at iteration 54 = 57.311658987513475
#
# Cost at iteration 55 = 56.50948021161144
#
# Cost at iteration 56 = 55.759607510426214
#
# Cost at iteration 57 = 55.03854802728383
#
# Cost at iteration 58 = 54.34032118174534
#
# Cost at iteration 59 = 53.66127659636307
#
# Cost at iteration 60 = 52.999844063279745
#
# Cost at iteration 61 = 52.35505744338892
#
# Cost at iteration 62 = 51.7263465350591
#
# Cost at iteration 63 = 51.11332057050535
#
# Cost at iteration 64 = 50.51574331861525
#
# Cost at iteration 65 = 49.9334716529107
#
# Cost at iteration 66 = 49.366461458534374
#
# Cost at iteration 67 = 48.814736816939025
#
# Cost at iteration 68 = 48.278393823337986
#
# Cost at iteration 69 = 47.75758023869857
#
# Cost at iteration 70 = 47.25249373781797
#
# Cost at iteration 71 = 46.763366121405404
#
# Cost at iteration 72 = 46.290457252800636
#
# Cost at iteration 73 = 45.83404122824054
#
# Cost at iteration 74 = 45.39439754806318
#
# Cost at iteration 75 = 44.971798185775874
#
# Cost at iteration 76 = 44.56649737203487
#
# Cost at iteration 77 = 44.178719501334676
#
# Cost at iteration 78 = 43.80864886499566
#
# Cost at iteration 79 = 43.45641899417303
#
# Cost at iteration 80 = 43.122103697650985
#
# Cost at iteration 81 = 42.805708790016105
#
# Cost at iteration 82 = 42.50716571883496
#
# Cost at iteration 83 = 42.22632665286199
#
# Cost at iteration 84 = 41.9629617094697
#
# Cost at iteration 85 = 41.71675808533539
#
# Cost at iteration 86 = 41.48732139406478
#
# Cost at iteration 87 = 41.27417898010713
#
# Cost at iteration 88 = 41.07678522362059
#
# Cost at iteration 89 = 40.894528529328326
#
# Cost at iteration 90 = 40.72673980235416
#
# Cost at iteration 91 = 40.57270202890717
#
# Cost at iteration 92 = 40.431660643376944
#
# Cost at iteration 93 = 40.30283427674503
#
# Cost at iteration 94 = 40.18542554252768
#
# Cost at iteration 95 = 40.07863150116485
#
# Cost at iteration 96 = 39.98165351583877
#
# Cost at iteration 97 = 39.89370624237476
#
# Cost at iteration 98 = 39.81402557350924
#
# Cost at iteration 99 = 39.74155351264072
#
# Cost at iteration 100 = 39.67500726913497
#
# Root Mean Squared error of the model:  11.171111680997502

# %% [markdown]
# --------------------------------------------------------------------------------------------
# #### **2. Making predictions to the seeds dataset using the Neural network built from scratch**

# %%
# Initialise the hyperparameters
num_iters = 1000                                                                  #set number of iterations over the training set(also known as epochs in batch gradient descent context)
learning_rate = 0.03
layer_sizes=[7,5,5,3]

df =  pd.read_csv('seeds.csv')
n=df.shape[1]
m=df.shape[0]

x_train=np.array(df.iloc[:int(0.9*m),:n-1])      # we take 90% of rows in training data
y_train=np.array(df.iloc[:int(0.9*m),-1])        # only the last column is in y_train  
x_test=np.array(df.iloc[int(0.9*m):,:n-1])       # only 10 % of rows is in testing dataset
y_test=np.array(df.iloc[int(0.9*m):,-1])         # splitting into training and testing dataset 
params = model(x_train, y_train, layer_sizes, num_iters, learning_rate)
y_predict = predict(x_test,params)

# for i in range(0, len(y_predict)):
#     if(y_predict[i]>=0.5):
#         y_predict[i]=1
#     else:
#         y_predict[i]=0

print(y_predict)
# Out:
# Cost at iteration 1 = 6.346144179581963
#
# Cost at iteration 2 = 6.344413631083732
#
# Cost at iteration 3 = 6.342683635135125
#
# Cost at iteration 4 = 6.3409541915871275
#
# Cost at iteration 5 = 6.339225300302825
#
# Cost at iteration 6 = 6.337496961036965
#
# Cost at iteration 7 = 6.335769173612687
#
# Cost at iteration 8 = 6.334041937887157
#
# Cost at iteration 9 = 6.332315253659583
#
# Cost at iteration 10 = 6.330589120743215
#
# Cost at iteration 11 = 6.328863538961421
#
# Cost at iteration 12 = 6.327138508137628
#
# Cost at iteration 13 = 6.325414028095316
#
# Cost at iteration 14 = 6.3236900986580284
#
# Cost at iteration 15 = 6.32196671964936
#
# Cost at iteration 16 = 6.320243890892969
#
# Cost at iteration 17 = 6.318521612281032
#
# Cost at iteration 18 = 6.316799883596457
#
# Cost at iteration 19 = 6.315078704635222
#
# Cost at iteration 20 = 6.313358075308924
#
# Cost at iteration 21 = 6.311637995448645
#
# Cost at iteration 22 = 6.309918464783063
#
# Cost at iteration 23 = 6.308199483136238
#
# Cost at iteration 24 = 6.306481050332283
#
# Cost at iteration 25 = 6.304763166279008
#
# Cost at iteration 26 = 6.3030458307293715
#
# Cost at iteration 27 = 6.3013290434482645
#
# Cost at iteration 28 = 6.299612804266813
#
# Cost at iteration 29 = 6.297897113048547
#
# Cost at iteration 30 = 6.2961819696189405
#
# Cost at iteration 31 = 6.294467373802506
#
# Cost at iteration 32 = 6.292753325423816
#
# Cost at iteration 33 = 6.291039824307502
#
# Cost at iteration 34 = 6.289326870278246
#
# Cost at iteration 35 = 6.287614463172486
#
# Cost at iteration 36 = 6.285902602832059
#
# Cost at iteration 37 = 6.2841912890529725
#
# Cost at iteration 38 = 6.282480521660139
#
# Cost at iteration 39 = 6.2807703004785305
#
# Cost at iteration 40 = 6.279060625333177
#
# Cost at iteration 41 = 6.27735149604916
#
# Cost at iteration 42 = 6.275642912451626
#
# Cost at iteration 43 = 6.2739348743657715
#
# Cost at iteration 44 = 6.272227381616851
#
# Cost at iteration 45 = 6.270520434030181
#
# Cost at iteration 46 = 6.268814031431124
#
# Cost at iteration 47 = 6.267108173648915
#
# Cost at iteration 48 = 6.26540286054283
#
# Cost at iteration 49 = 6.263698091900685
#
# Cost at iteration 50 = 6.2619938675480755
#
# Cost at iteration 51 = 6.260290187324813
#
# Cost at iteration 52 = 6.25858705106924
#
# Cost at iteration 53 = 6.256884458580214
#
# Cost at iteration 54 = 6.255182409683552
#
# Cost at iteration 55 = 6.25348090420514
#
# Cost at iteration 56 = 6.2517799419709075
#
# Cost at iteration 57 = 6.2500795228068515
#
# Cost at iteration 58 = 6.2483796465390204
#
# Cost at iteration 59 = 6.246680312993524
#
# Cost at iteration 60 = 6.244981521996518
#
# Cost at iteration 61 = 6.243283273374225
#
# Cost at iteration 62 = 6.2415855669529225
#
# Cost at iteration 63 = 6.2398884026425945
#
# Cost at iteration 64 = 6.238191780186753
#
# Cost at iteration 65 = 6.236495699495355
#
# Cost at iteration 66 = 6.234800160310182
#
# Cost at iteration 67 = 6.233105162457795
#
# Cost at iteration 68 = 6.231410705791549
#
# Cost at iteration 69 = 6.229716790171161
#
# Cost at iteration 70 = 6.228023415363352
#
# Cost at iteration 71 = 6.2263305811949055
#
# Cost at iteration 72 = 6.224638287523706
#
# Cost at iteration 73 = 6.22294653415458
#
# Cost at iteration 74 = 6.221255320905388
#
# Cost at iteration 75 = 6.2195646476031365
#
# Cost at iteration 76 = 6.217874514149522
#
# Cost at iteration 77 = 6.216184920308568
#
# Cost at iteration 78 = 6.214495865895699
#
# Cost at iteration 79 = 6.212807350738154
#
# Cost at iteration 80 = 6.21111937466322
#
# Cost at iteration 81 = 6.2094319374982465
#
# Cost at iteration 82 = 6.207745039100728
#
# Cost at iteration 83 = 6.206058679312121
#
# Cost at iteration 84 = 6.204372857956186
#
# Cost at iteration 85 = 6.202687574819811
#
# Cost at iteration 86 = 6.201002829730632
#
# Cost at iteration 87 = 6.199318622516324
#
# Cost at iteration 88 = 6.197634953004629
#
# Cost at iteration 89 = 6.1959518210233435
#
# Cost at iteration 90 = 6.1942692264003165
#
# Cost at iteration 91 = 6.192587168963457
#
# Cost at iteration 92 = 6.190905648613834
#
# Cost at iteration 93 = 6.189224665120464
#
# Cost at iteration 94 = 6.187544218297098
#
# Cost at iteration 95 = 6.185864307971863
#
# Cost at iteration 96 = 6.184184933972946
#
# Cost at iteration 97 = 6.182506096128593
#
# Cost at iteration 98 = 6.180827794267098
#
# Cost at iteration 99 = 6.179150028254407
#
# Cost at iteration 100 = 6.1774727978821335
#
# Cost at iteration 101 = 6.175796102977834
#
# Cost at iteration 102 = 6.174119943370028
#
# Cost at iteration 103 = 6.172444318887291
#
# Cost at iteration 104 = 6.170769229358258
#
# Cost at iteration 105 = 6.169094674611613
#
# Cost at iteration 106 = 6.1674206544761025
#
# Cost at iteration 107 = 6.165747168780524
#
# Cost at iteration 108 = 6.1640742173537335
#
# Cost at iteration 109 = 6.162401800024638
#
# Cost at iteration 110 = 6.160729916622206
#
# Cost at iteration 111 = 6.159058567048482
#
# Cost at iteration 112 = 6.157387751071591
#
# Cost at iteration 113 = 6.155717468508376
#
# Cost at iteration 114 = 6.154047719188028
#
# Cost at iteration 115 = 6.15237850293979
#
# Cost at iteration 116 = 6.150709819592959
#
# Cost at iteration 117 = 6.149041668976888
#
# Cost at iteration 118 = 6.147374050920987
#
# Cost at iteration 119 = 6.145706965250819
#
# Cost at iteration 120 = 6.144040411799616
#
# Cost at iteration 121 = 6.142374390397146
#
# Cost at iteration 122 = 6.14070890087304
#
# Cost at iteration 123 = 6.1390439430569845
#
# Cost at iteration 124 = 6.137379516778719
#
# Cost at iteration 125 = 6.135715621868041
#
# Cost at iteration 126 = 6.134052258154799
#
# Cost at iteration 127 = 6.1323894254689035
#
# Cost at iteration 128 = 6.130727123640312
#
# Cost at iteration 129 = 6.129065352500619
#
# Cost at iteration 130 = 6.127404111957841
#
# Cost at iteration 131 = 6.12574340176238
#
# Cost at iteration 132 = 6.124083221744421
#
# Cost at iteration 133 = 6.122423571804384
#
# Cost at iteration 134 = 6.12076445171284
#
# Cost at iteration 135 = 6.119105861289475
#
# Cost at iteration 136 = 6.117447800360828
#
# Cost at iteration 137 = 6.115790268760484
#
# Cost at iteration 138 = 6.114133266319695
#
# Cost at iteration 139 = 6.112476792869032
#
# Cost at iteration 140 = 6.110820848239116
#
# Cost at iteration 141 = 6.109165432260622
#
# Cost at iteration 142 = 6.107510544764286
#
# Cost at iteration 143 = 6.105856185639882
#
# Cost at iteration 144 = 6.104202354713718
#
# Cost at iteration 145 = 6.1025490517619385
#
# Cost at iteration 146 = 6.100896276615495
#
# Cost at iteration 147 = 6.099244029105394
#
# Cost at iteration 148 = 6.0975923090627004
#
# Cost at iteration 149 = 6.095941116318529
#
# Cost at iteration 150 = 6.094290450718622
#
# Cost at iteration 151 = 6.092640312127915
#
# Cost at iteration 152 = 6.090990700338366
#
# Cost at iteration 153 = 6.089341615185533
#
# Cost at iteration 154 = 6.0876930565100436
#
# Cost at iteration 155 = 6.086045024116177
#
# Cost at iteration 156 = 6.084397517839869
#
# Cost at iteration 157 = 6.082750537512675
#
# Cost at iteration 158 = 6.081104082990321
#
# Cost at iteration 159 = 6.079458154090149
#
# Cost at iteration 160 = 6.077812750633983
#
# Cost at iteration 161 = 6.076167872453594
#
# Cost at iteration 162 = 6.074523519380811
#
# Cost at iteration 163 = 6.072879691247519
#
# Cost at iteration 164 = 6.071236387885651
#
# Cost at iteration 165 = 6.069593609127199
#
# Cost at iteration 166 = 6.067951354804207
#
# Cost at iteration 167 = 6.06630962474878
#
# Cost at iteration 168 = 6.0646684188055024
#
# Cost at iteration 169 = 6.063027736814777
#
# Cost at iteration 170 = 6.06138757858814
#
# Cost at iteration 171 = 6.059747943957911
#
# Cost at iteration 172 = 6.058108832756462
#
# Cost at iteration 173 = 6.056470244816219
#
# Cost at iteration 174 = 6.054832179997012
#
# Cost at iteration 175 = 6.053194638110491
#
# Cost at iteration 176 = 6.051557618982681
#
# Cost at iteration 177 = 6.049921122446224
#
# Cost at iteration 178 = 6.048285148333819
#
# Cost at iteration 179 = 6.046649696478218
#
# Cost at iteration 180 = 6.045014766712223
#
# Cost at iteration 181 = 6.043380358868697
#
# Cost at iteration 182 = 6.041746472780555
#
# Cost at iteration 183 = 6.040113108280766
#
# Cost at iteration 184 = 6.038480265202348
#
# Cost at iteration 185 = 6.036847943378381
#
# Cost at iteration 186 = 6.035216142641992
#
# Cost at iteration 187 = 6.033584862826368
#
# Cost at iteration 188 = 6.031954103800379
#
# Cost at iteration 189 = 6.030323865403538
#
# Cost at iteration 190 = 6.028694147427151
#
# Cost at iteration 191 = 6.027064949704615
#
# Cost at iteration 192 = 6.025436272069386
#
# Cost at iteration 193 = 6.02380811435497
#
# Cost at iteration 194 = 6.022180476394935
#
# Cost at iteration 195 = 6.020553358022891
#
# Cost at iteration 196 = 6.018926759072513
#
# Cost at iteration 197 = 6.017300679377524
#
# Cost at iteration 198 = 6.015675118771699
#
# Cost at iteration 199 = 6.014050077109344
#
# Cost at iteration 200 = 6.01242555423664
#
# Cost at iteration 201 = 6.010801549966048
#
# Cost at iteration 202 = 6.009178064120079
#
# Cost at iteration 203 = 6.007555096563812
#
# Cost at iteration 204 = 6.005932647101672
#
# Cost at iteration 205 = 6.004310715566366
#
# Cost at iteration 206 = 6.002689301792103
#
# Cost at iteration 207 = 6.001068405613146
#
# Cost at iteration 208 = 5.9994480268638055
#
# Cost at iteration 209 = 5.997828165378458
#
# Cost at iteration 210 = 5.99620882099152
#
# Cost at iteration 211 = 5.994589993537473
#
# Cost at iteration 212 = 5.992971682850845
#
# Cost at iteration 213 = 5.991353888766219
#
# Cost at iteration 214 = 5.989736611118233
#
# Cost at iteration 215 = 5.988119849741577
#
# Cost at iteration 216 = 5.986503604470995
#
# Cost at iteration 217 = 5.9848878751412835
#
# Cost at iteration 218 = 5.983272661597208
#
# Cost at iteration 219 = 5.981657963686208
#
# Cost at iteration 220 = 5.980043781220697
#
# Cost at iteration 221 = 5.97843011403569
#
# Cost at iteration 222 = 5.976816961966249
#
# Cost at iteration 223 = 5.975204324847493
#
# Cost at iteration 224 = 5.973592202514592
#
# Cost at iteration 225 = 5.971980594802774
#
# Cost at iteration 226 = 5.9703695015473155
#
# Cost at iteration 227 = 5.968758922583546
#
# Cost at iteration 228 = 5.967148857746852
#
# Cost at iteration 229 = 5.965539306872672
#
# Cost at iteration 230 = 5.963930269796495
#
# Cost at iteration 231 = 5.962321746353868
#
# Cost at iteration 232 = 5.960713736380507
#
# Cost at iteration 233 = 5.95910623974283
#
# Cost at iteration 234 = 5.957499256245564
#
# Cost at iteration 235 = 5.9558927857244655
#
# Cost at iteration 236 = 5.954286828015344
#
# Cost at iteration 237 = 5.952681382954064
#
# Cost at iteration 238 = 5.951076450376541
#
# Cost at iteration 239 = 5.949472030118747
#
# Cost at iteration 240 = 5.947868122016701
#
# Cost at iteration 241 = 5.946264725906482
#
# Cost at iteration 242 = 5.944661841624216
#
# Cost at iteration 243 = 5.943059469021471
#
# Cost at iteration 244 = 5.941457607934518
#
# Cost at iteration 245 = 5.939856258184131
#
# Cost at iteration 246 = 5.938255419606655
#
# Cost at iteration 247 = 5.93665509203848
#
# Cost at iteration 248 = 5.935055275316054
#
# Cost at iteration 249 = 5.933455969275876
#
# Cost at iteration 250 = 5.931857173754496
#
# Cost at iteration 251 = 5.930258888588524
#
# Cost at iteration 252 = 5.928661113614615
#
# Cost at iteration 253 = 5.927063848669478
#
# Cost at iteration 254 = 5.925467093589879
#
# Cost at iteration 255 = 5.923870848235327
#
# Cost at iteration 256 = 5.922275112427601
#
# Cost at iteration 257 = 5.920679885995931
#
# Cost at iteration 258 = 5.919085168777336
#
# Cost at iteration 259 = 5.917490960639195
#
# Cost at iteration 260 = 5.915897261428319
#
# Cost at iteration 261 = 5.91430407096226
#
# Cost at iteration 262 = 5.912711389054697
#
# Cost at iteration 263 = 5.911119215575204
#
# Cost at iteration 264 = 5.909527550368076
#
# Cost at iteration 265 = 5.907936393233854
#
# Cost at iteration 266 = 5.906345744009932
#
# Cost at iteration 267 = 5.904755602528538
#
# Cost at iteration 268 = 5.903165968627131
#
# Cost at iteration 269 = 5.90157684217033
#
# Cost at iteration 270 = 5.899988222982047
#
# Cost at iteration 271 = 5.8984001108917505
#
# Cost at iteration 272 = 5.896812505737156
#
# Cost at iteration 273 = 5.895225407356025
#
# Cost at iteration 274 = 5.8936388155861765
#
# Cost at iteration 275 = 5.892052730265477
#
# Cost at iteration 276 = 5.890467151235044
#
# Cost at iteration 277 = 5.888882078358305
#
# Cost at iteration 278 = 5.887297511476231
#
# Cost at iteration 279 = 5.88571345039566
#
# Cost at iteration 280 = 5.884129894969221
#
# Cost at iteration 281 = 5.882546845034989
#
# Cost at iteration 282 = 5.880964300416187
#
# Cost at iteration 283 = 5.879382260951104
#
# Cost at iteration 284 = 5.877800726504462
#
# Cost at iteration 285 = 5.876219696928749
#
# Cost at iteration 286 = 5.874639172021773
#
# Cost at iteration 287 = 5.873059151622028
#
# Cost at iteration 288 = 5.871479635568067
#
# Cost at iteration 289 = 5.8699006236984905
#
# Cost at iteration 290 = 5.868322115851954
#
# Cost at iteration 291 = 5.866744111867162
#
# Cost at iteration 292 = 5.865166611582873
#
# Cost at iteration 293 = 5.863589614837895
#
# Cost at iteration 294 = 5.8620131214710955
#
# Cost at iteration 295 = 5.860437131321385
#
# Cost at iteration 296 = 5.858861644227732
#
# Cost at iteration 297 = 5.857286660074642
#
# Cost at iteration 298 = 5.8557121786965185
#
# Cost at iteration 299 = 5.854138199891414
#
# Cost at iteration 300 = 5.852564723498504
#
# Cost at iteration 301 = 5.850991749357013
#
# Cost at iteration 302 = 5.849419277306224
#
# Cost at iteration 303 = 5.847847307185465
#
# Cost at iteration 304 = 5.84627583883412
#
# Cost at iteration 305 = 5.84470487209162
#
# Cost at iteration 306 = 5.843134406797454
#
# Cost at iteration 307 = 5.841564442791162
#
# Cost at iteration 308 = 5.839994979912331
#
# Cost at iteration 309 = 5.838426018000603
#
# Cost at iteration 310 = 5.836857556895673
#
# Cost at iteration 311 = 5.835289596437286
#
# Cost at iteration 312 = 5.833722136465239
#
# Cost at iteration 313 = 5.832155176823602
#
# Cost at iteration 314 = 5.830588717372536
#
# Cost at iteration 315 = 5.829022757927427
#
# Cost at iteration 316 = 5.827457298328282
#
# Cost at iteration 317 = 5.825892338415155
#
# Cost at iteration 318 = 5.824327878028152
#
# Cost at iteration 319 = 5.8227639170074355
#
# Cost at iteration 320 = 5.82120045521872
#
# Cost at iteration 321 = 5.819637492480009
#
# Cost at iteration 322 = 5.818075028628283
#
# Cost at iteration 323 = 5.816513063503914
#
# Cost at iteration 324 = 5.814951596947316
#
# Cost at iteration 325 = 5.813390628809904
#
# Cost at iteration 326 = 5.811830158937412
#
# Cost at iteration 327 = 5.810270187154174
#
# Cost at iteration 328 = 5.808710713300811
#
# Cost at iteration 329 = 5.807151737217998
#
# Cost at iteration 330 = 5.8055932587464625
#
# Cost at iteration 331 = 5.80403527772698
#
# Cost at iteration 332 = 5.802477794000383
#
# Cost at iteration 333 = 5.800920807407547
#
# Cost at iteration 334 = 5.799364317789405
#
# Cost at iteration 335 = 5.797808324986942
#
# Cost at iteration 336 = 5.7962528288411885
#
# Cost at iteration 337 = 5.794697829193234
#
# Cost at iteration 338 = 5.7931433258842135
#
# Cost at iteration 339 = 5.791589318755314
#
# Cost at iteration 340 = 5.790035807647776
#
# Cost at iteration 341 = 5.788482792402891
#
# Cost at iteration 342 = 5.786930272861998
#
# Cost at iteration 343 = 5.7853782488664915
#
# Cost at iteration 344 = 5.7838267202578155
#
# Cost at iteration 345 = 5.782275686877467
#
# Cost at iteration 346 = 5.7807251485831825
#
# Cost at iteration 347 = 5.779175105210912
#
# Cost at iteration 348 = 5.777625556591683
#
# Cost at iteration 349 = 5.7760765025672
#
# Cost at iteration 350 = 5.774527942979206
#
# Cost at iteration 351 = 5.77297987766951
#
# Cost at iteration 352 = 5.771432306479961
#
# Cost at iteration 353 = 5.769885229252465
#
# Cost at iteration 354 = 5.768338645828979
#
# Cost at iteration 355 = 5.766792556051505
#
# Cost at iteration 356 = 5.765246959762103
#
# Cost at iteration 357 = 5.7637018568028795
#
# Cost at iteration 358 = 5.762157247015995
#
# Cost at iteration 359 = 5.760613130243661
#
# Cost at iteration 360 = 5.759069506328136
#
# Cost at iteration 361 = 5.75752637511173
#
# Cost at iteration 362 = 5.755983736433138
#
# Cost at iteration 363 = 5.754441590157314
#
# Cost at iteration 364 = 5.7528999361160436
#
# Cost at iteration 365 = 5.751358774155473
#
# Cost at iteration 366 = 5.749818104119456
#
# Cost at iteration 367 = 5.748277925841687
#
# Cost at iteration 368 = 5.746738239182346
#
# Cost at iteration 369 = 5.745199043962229
#
# Cost at iteration 370 = 5.743660340024107
#
# Cost at iteration 371 = 5.742122127210798
#
# Cost at iteration 372 = 5.740584405385198
#
# Cost at iteration 373 = 5.739047174377582
#
# Cost at iteration 374 = 5.737510434023471
#
# Cost at iteration 375 = 5.73597418416588
#
# Cost at iteration 376 = 5.7344384246478874
#
# Cost at iteration 377 = 5.732903155312619
#
# Cost at iteration 378 = 5.731368376003245
#
# Cost at iteration 379 = 5.729834086562994
#
# Cost at iteration 380 = 5.728300286835142
#
# Cost at iteration 381 = 5.726766976663017
#
# Cost at iteration 382 = 5.725234155889991
#
# Cost at iteration 383 = 5.723701824359496
#
# Cost at iteration 384 = 5.722169981915009
#
# Cost at iteration 385 = 5.720638628400059
#
# Cost at iteration 386 = 5.719107763658224
#
# Cost at iteration 387 = 5.717577387533135
#
# Cost at iteration 388 = 5.716047499868471
#
# Cost at iteration 389 = 5.714518100507963
#
# Cost at iteration 390 = 5.7129891892953895
#
# Cost at iteration 391 = 5.711460766074584
#
# Cost at iteration 392 = 5.709932830689428
#
# Cost at iteration 393 = 5.708405382983851
#
# Cost at iteration 394 = 5.706878422801838
#
# Cost at iteration 395 = 5.70535194998742
#
# Cost at iteration 396 = 5.703825964384679
#
# Cost at iteration 397 = 5.702300465837749
#
# Cost at iteration 398 = 5.700775454190812
#
# Cost at iteration 399 = 5.699250929288104
#
# Cost at iteration 400 = 5.697726890973907
#
# Cost at iteration 401 = 5.6962033390925555
#
# Cost at iteration 402 = 5.694680273488432
#
# Cost at iteration 403 = 5.693157694005971
#
# Cost at iteration 404 = 5.6916356004896596
#
# Cost at iteration 405 = 5.690113992784029
#
# Cost at iteration 406 = 5.688592870733667
#
# Cost at iteration 407 = 5.687072234183207
#
# Cost at iteration 408 = 5.685552082977332
#
# Cost at iteration 409 = 5.684032416960778
#
# Cost at iteration 410 = 5.682513235978333
#
# Cost at iteration 411 = 5.680994539889478
#
# Cost at iteration 412 = 5.679476328533189
#
# Cost at iteration 413 = 5.677958601745592
#
# Cost at iteration 414 = 5.676441359371679
#
# Cost at iteration 415 = 5.67492460125648
#
# Cost at iteration 416 = 5.673408327245081
#
# Cost at iteration 417 = 5.671892537182617
#
# Cost at iteration 418 = 5.670377230914275
#
# Cost at iteration 419 = 5.668862408285287
#
# Cost at iteration 420 = 5.6673480691409415
#
# Cost at iteration 421 = 5.665834213326567
#
# Cost at iteration 422 = 5.664320840687553
#
# Cost at iteration 423 = 5.6628079510693325
#
# Cost at iteration 424 = 5.6612955443173885
#
# Cost at iteration 425 = 5.6597836202772545
#
# Cost at iteration 426 = 5.658272178794519
#
# Cost at iteration 427 = 5.6567612197148085
#
# Cost at iteration 428 = 5.655250742883809
#
# Cost at iteration 429 = 5.653740748147254
#
# Cost at iteration 430 = 5.652231235350927
#
# Cost at iteration 431 = 5.650722204340658
#
# Cost at iteration 432 = 5.649213654962329
#
# Cost at iteration 433 = 5.647705587061874
#
# Cost at iteration 434 = 5.646198000485272
#
# Cost at iteration 435 = 5.644690895078555
#
# Cost at iteration 436 = 5.643184270687804
#
# Cost at iteration 437 = 5.641678127164596
#
# Cost at iteration 438 = 5.640172464368451
#
# Cost at iteration 439 = 5.638667282126743
#
# Cost at iteration 440 = 5.63716258028575
#
# Cost at iteration 441 = 5.635658358691799
#
# Cost at iteration 442 = 5.63415461719127
#
# Cost at iteration 443 = 5.632651355630591
#
# Cost at iteration 444 = 5.631148573856238
#
# Cost at iteration 445 = 5.629646271714736
#
# Cost at iteration 446 = 5.628144449073884
#
# Cost at iteration 447 = 5.626643105762445
#
# Cost at iteration 448 = 5.625142241624848
#
# Cost at iteration 449 = 5.623641856526953
#
# Cost at iteration 450 = 5.6221419502951555
#
# Cost at iteration 451 = 5.620642522776277
#
# Cost at iteration 452 = 5.619143573817191
#
# Cost at iteration 453 = 5.617645103264818
#
# Cost at iteration 454 = 5.616147110966131
#
# Cost at iteration 455 = 5.614649596768149
#
# Cost at iteration 456 = 5.613152560517942
#
# Cost at iteration 457 = 5.61165600206263
#
# Cost at iteration 458 = 5.610159921249382
#
# Cost at iteration 459 = 5.608664317925411
#
# Cost at iteration 460 = 5.607169191937988
#
# Cost at iteration 461 = 5.605674543134429
#
# Cost at iteration 462 = 5.6041803713620935
#
# Cost at iteration 463 = 5.6026866764684025
#
# Cost at iteration 464 = 5.601193458300817
#
# Cost at iteration 465 = 5.59970071670685
#
# Cost at iteration 466 = 5.5982084515340595
#
# Cost at iteration 467 = 5.596716662630062
#
# Cost at iteration 468 = 5.595225349842512
#
# Cost at iteration 469 = 5.593734513019123
#
# Cost at iteration 470 = 5.592244152007649
#
# Cost at iteration 471 = 5.590754266655899
#
# Cost at iteration 472 = 5.589264856811728
#
# Cost at iteration 473 = 5.587775922323041
#
# Cost at iteration 474 = 5.586287463037794
#
# Cost at iteration 475 = 5.584799478803989
#
# Cost at iteration 476 = 5.583311969469675
#
# Cost at iteration 477 = 5.581824934882956
#
# Cost at iteration 478 = 5.58033837489198
#
# Cost at iteration 479 = 5.5788522893449475
#
# Cost at iteration 480 = 5.5773666780901054
#
# Cost at iteration 481 = 5.5758815409757485
#
# Cost at iteration 482 = 5.574396877850223
#
# Cost at iteration 483 = 5.572912688561923
#
# Cost at iteration 484 = 5.571428972959292
#
# Cost at iteration 485 = 5.56994573089082
#
# Cost at iteration 486 = 5.568462962205049
#
# Cost at iteration 487 = 5.566980666757679
#
# Cost at iteration 488 = 5.565498844405662
#
# Cost at iteration 489 = 5.564017494990754
#
# Cost at iteration 490 = 5.5625366183660425
#
# Cost at iteration 491 = 5.561056214367343
#
# Cost at iteration 492 = 5.559576284899235
#
# Cost at iteration 493 = 5.55809682882807
#
# Cost at iteration 494 = 5.556617846370393
#
# Cost at iteration 495 = 5.555139336221087
#
# Cost at iteration 496 = 5.553661298436647
#
# Cost at iteration 497 = 5.552183733535492
#
# Cost at iteration 498 = 5.5507066414889765
#
# Cost at iteration 499 = 5.549230023289464
#
# Cost at iteration 500 = 5.54775387857527
#
# Cost at iteration 501 = 5.546278207781233
#
# Cost at iteration 502 = 5.544803012158688
#
# Cost at iteration 503 = 5.543328292864353
#
# Cost at iteration 504 = 5.541854046660001
#
# Cost at iteration 505 = 5.540380272910839
#
# Cost at iteration 506 = 5.538906973097937
#
# Cost at iteration 507 = 5.537434146929777
#
# Cost at iteration 508 = 5.53596179790913
#
# Cost at iteration 509 = 5.534489923048919
#
# Cost at iteration 510 = 5.533018518758877
#
# Cost at iteration 511 = 5.531547584465832
#
# Cost at iteration 512 = 5.530077122380402
#
# Cost at iteration 513 = 5.528607132356843
#
# Cost at iteration 514 = 5.527137614544335
#
# Cost at iteration 515 = 5.525668567398287
#
# Cost at iteration 516 = 5.524199992933254
#
# Cost at iteration 517 = 5.522731891591985
#
# Cost at iteration 518 = 5.521264261431866
#
# Cost at iteration 519 = 5.519797100658606
#
# Cost at iteration 520 = 5.5183304089306615
#
# Cost at iteration 521 = 5.516864185825243
#
# Cost at iteration 522 = 5.515398435977668
#
# Cost at iteration 523 = 5.513933159029838
#
# Cost at iteration 524 = 5.512468351596573
#
# Cost at iteration 525 = 5.511004015252703
#
# Cost at iteration 526 = 5.509540147574994
#
# Cost at iteration 527 = 5.508076750742305
#
# Cost at iteration 528 = 5.50661382218203
#
# Cost at iteration 529 = 5.5051513635271405
#
# Cost at iteration 530 = 5.503689373482136
#
# Cost at iteration 531 = 5.502227851851354
#
# Cost at iteration 532 = 5.500766801833328
#
# Cost at iteration 533 = 5.499306223075375
#
# Cost at iteration 534 = 5.497846119097758
#
# Cost at iteration 535 = 5.496386490236222
#
# Cost at iteration 536 = 5.494927336418748
#
# Cost at iteration 537 = 5.493468655072373
#
# Cost at iteration 538 = 5.492010444175894
#
# Cost at iteration 539 = 5.490552702159308
#
# Cost at iteration 540 = 5.48909542908012
#
# Cost at iteration 541 = 5.487638624644213
#
# Cost at iteration 542 = 5.486182289299665
#
# Cost at iteration 543 = 5.484726420877371
#
# Cost at iteration 544 = 5.4832710250627175
#
# Cost at iteration 545 = 5.481816102219505
#
# Cost at iteration 546 = 5.480361646911481
#
# Cost at iteration 547 = 5.478907656664253
#
# Cost at iteration 548 = 5.477454134788331
#
# Cost at iteration 549 = 5.476001078741363
#
# Cost at iteration 550 = 5.474548487202831
#
# Cost at iteration 551 = 5.473096362037057
#
# Cost at iteration 552 = 5.471644700812449
#
# Cost at iteration 553 = 5.470193503904475
#
# Cost at iteration 554 = 5.468742771007528
#
# Cost at iteration 555 = 5.467292501040455
#
# Cost at iteration 556 = 5.465842693855475
#
# Cost at iteration 557 = 5.464393349889031
#
# Cost at iteration 558 = 5.462944470354571
#
# Cost at iteration 559 = 5.461496053388973
#
# Cost at iteration 560 = 5.460048098612727
#
# Cost at iteration 561 = 5.458600605878386
#
# Cost at iteration 562 = 5.4571535750384506
#
# Cost at iteration 563 = 5.455707005945463
#
# Cost at iteration 564 = 5.454260898452016
#
# Cost at iteration 565 = 5.452815252410747
#
# Cost at iteration 566 = 5.4513700676743415
#
# Cost at iteration 567 = 5.449925344095535
#
# Cost at iteration 568 = 5.448481081527102
#
# Cost at iteration 569 = 5.447037279821873
#
# Cost at iteration 570 = 5.44559393883272
#
# Cost at iteration 571 = 5.444151058412564
#
# Cost at iteration 572 = 5.442708638414375
#
# Cost at iteration 573 = 5.441266678691163
#
# Cost at iteration 574 = 5.439825179095994
#
# Cost at iteration 575 = 5.438384139481974
#
# Cost at iteration 576 = 5.436943559702259
#
# Cost at iteration 577 = 5.435503439610052
#
# Cost at iteration 578 = 5.434063779058601
#
# Cost at iteration 579 = 5.432624577901203
#
# Cost at iteration 580 = 5.431185835991201
#
# Cost at iteration 581 = 5.429747553181984
#
# Cost at iteration 582 = 5.4283097293269895
#
# Cost at iteration 583 = 5.4268723642797
#
# Cost at iteration 584 = 5.425435457893647
#
# Cost at iteration 585 = 5.423999010022406
#
# Cost at iteration 586 = 5.422563020519603
#
# Cost at iteration 587 = 5.4211274892389065
#
# Cost at iteration 588 = 5.419692416034035
#
# Cost at iteration 589 = 5.418257800758751
#
# Cost at iteration 590 = 5.4168236432511065
#
# Cost at iteration 591 = 5.4153899433745645
#
# Cost at iteration 592 = 5.413956700989101
#
# Cost at iteration 593 = 5.412523915948671
#
# Cost at iteration 594 = 5.411091588107268
#
# Cost at iteration 595 = 5.409659717318937
#
# Cost at iteration 596 = 5.40822830343777
#
# Cost at iteration 597 = 5.406797346317903
#
# Cost at iteration 598 = 5.405366845810755
#
# Cost at iteration 599 = 5.40393680176938
#
# Cost at iteration 600 = 5.402507214051976
#
# Cost at iteration 601 = 5.401078082512869
#
# Cost at iteration 602 = 5.399649407006428
#
# Cost at iteration 603 = 5.398221187387071
#
# Cost at iteration 604 = 5.3967934235092585
#
# Cost at iteration 605 = 5.395366115227503
#
# Cost at iteration 606 = 5.39393926239636
#
# Cost at iteration 607 = 5.3925128648704295
#
# Cost at iteration 608 = 5.391086922504364
#
# Cost at iteration 609 = 5.389661435152857
#
# Cost at iteration 610 = 5.388236402669269
#
# Cost at iteration 611 = 5.386811824888968
#
# Cost at iteration 612 = 5.385387701687512
#
# Cost at iteration 613 = 5.383964032919782
#
# Cost at iteration 614 = 5.382540818440706
#
# Cost at iteration 615 = 5.381118058105256
#
# Cost at iteration 616 = 5.379695751768453
#
# Cost at iteration 617 = 5.3782738992853645
#
# Cost at iteration 618 = 5.376852500511101
#
# Cost at iteration 619 = 5.375431555300823
#
# Cost at iteration 620 = 5.374011063509736
#
# Cost at iteration 621 = 5.372591024992404
#
# Cost at iteration 622 = 5.371171439592468
#
# Cost at iteration 623 = 5.36975230717758
#
# Cost at iteration 624 = 5.368333627603128
#
# Cost at iteration 625 = 5.366915400724553
#
# Cost at iteration 626 = 5.365497626397332
#
# Cost at iteration 627 = 5.364080304476997
#
# Cost at iteration 628 = 5.362663434819122
#
# Cost at iteration 629 = 5.361247017279328
#
# Cost at iteration 630 = 5.359831051713282
#
# Cost at iteration 631 = 5.358415537976699
#
# Cost at iteration 632 = 5.357000475925335
#
# Cost at iteration 633 = 5.355585865414998
#
# Cost at iteration 634 = 5.354171706301538
#
# Cost at iteration 635 = 5.352757998440854
#
# Cost at iteration 636 = 5.351344741688888
#
# Cost at iteration 637 = 5.34993193590163
#
# Cost at iteration 638 = 5.3485195809351165
#
# Cost at iteration 639 = 5.347107676645427
#
# Cost at iteration 640 = 5.345696222888691
#
# Cost at iteration 641 = 5.344285219521081
#
# Cost at iteration 642 = 5.342874666398816
#
# Cost at iteration 643 = 5.341464563378161
#
# Cost at iteration 644 = 5.340054910315429
#
# Cost at iteration 645 = 5.338645707066974
#
# Cost at iteration 646 = 5.337236953489204
#
# Cost at iteration 647 = 5.335828649438562
#
# Cost at iteration 648 = 5.334420794771547
#
# Cost at iteration 649 = 5.333013389344696
#
# Cost at iteration 650 = 5.331606433014599
#
# Cost at iteration 651 = 5.330199925637886
#
# Cost at iteration 652 = 5.3287938670712345
#
# Cost at iteration 653 = 5.327388257171369
#
# Cost at iteration 654 = 5.32598309579506
#
# Cost at iteration 655 = 5.32457838279912
#
# Cost at iteration 656 = 5.323174118040412
#
# Cost at iteration 657 = 5.321770301375843
#
# Cost at iteration 658 = 5.320366932662363
#
# Cost at iteration 659 = 5.318964011756973
#
# Cost at iteration 660 = 5.317561538516716
#
# Cost at iteration 661 = 5.31615951279868
#
# Cost at iteration 662 = 5.314757934459999
#
# Cost at iteration 663 = 5.313356803357857
#
# Cost at iteration 664 = 5.311956119349479
#
# Cost at iteration 665 = 5.310555882292135
#
# Cost at iteration 666 = 5.309156092043145
#
# Cost at iteration 667 = 5.307756748459871
#
# Cost at iteration 668 = 5.306357851399721
#
# Cost at iteration 669 = 5.30495940072015
#
# Cost at iteration 670 = 5.303561396278658
#
# Cost at iteration 671 = 5.302163837932787
#
# Cost at iteration 672 = 5.300766725540132
#
# Cost at iteration 673 = 5.299370058958327
#
# Cost at iteration 674 = 5.2979738380450545
#
# Cost at iteration 675 = 5.29657806265804
#
# Cost at iteration 676 = 5.295182732655057
#
# Cost at iteration 677 = 5.293787847893924
#
# Cost at iteration 678 = 5.2923934082325035
#
# Cost at iteration 679 = 5.290999413528704
#
# Cost at iteration 680 = 5.289605863640481
#
# Cost at iteration 681 = 5.288212758425832
#
# Cost at iteration 682 = 5.286820097737519
#
# Cost at iteration 683 = 5.285427881436664
#
# Cost at iteration 684 = 5.284036109383639
#
# Cost at iteration 685 = 5.28264478143662
#
# Cost at iteration 686 = 5.281253897453835
#
# Cost at iteration 687 = 5.2798634572935566
#
# Cost at iteration 688 = 5.2784734608141
#
# Cost at iteration 689 = 5.277083907873826
#
# Cost at iteration 690 = 5.275694798331145
#
# Cost at iteration 691 = 5.274306132044367
#
# Cost at iteration 692 = 5.272917908865359
#
# Cost at iteration 693 = 5.2715301286594185
#
# Cost at iteration 694 = 5.270142791285133
#
# Cost at iteration 695 = 5.268755896601136
#
# Cost at iteration 696 = 5.267369444466107
#
# Cost at iteration 697 = 5.265983434738767
#
# Cost at iteration 698 = 5.264597867277886
#
# Cost at iteration 699 = 5.263212741942278
#
# Cost at iteration 700 = 5.261828058590801
#
# Cost at iteration 701 = 5.260443817082359
#
# Cost at iteration 702 = 5.2590600172759014
#
# Cost at iteration 703 = 5.2576766590304205
#
# Cost at iteration 704 = 5.256293742204957
#
# Cost at iteration 705 = 5.2549112666585955
#
# Cost at iteration 706 = 5.253529232250462
#
# Cost at iteration 707 = 5.252147638839735
#
# Cost at iteration 708 = 5.250766486285629
#
# Cost at iteration 709 = 5.24938577444741
#
# Cost at iteration 710 = 5.248005503184388
#
# Cost at iteration 711 = 5.246625672355916
#
# Cost at iteration 712 = 5.24524628182139
#
# Cost at iteration 713 = 5.243867331440258
#
# Cost at iteration 714 = 5.242488821072006
#
# Cost at iteration 715 = 5.241110750576168
#
# Cost at iteration 716 = 5.239733119812322
#
# Cost at iteration 717 = 5.238355928640092
#
# Cost at iteration 718 = 5.236979176919145
#
# Cost at iteration 719 = 5.235602864509194
#
# Cost at iteration 720 = 5.234226991269997
#
# Cost at iteration 721 = 5.232851557061355
#
# Cost at iteration 722 = 5.231476561743118
#
# Cost at iteration 723 = 5.230102005175176
#
# Cost at iteration 724 = 5.228727887197498
#
# Cost at iteration 725 = 5.227354207687204
#
# Cost at iteration 726 = 5.225980966507081
#
# Cost at iteration 727 = 5.2246081635172
#
# Cost at iteration 728 = 5.223235798577676
#
# Cost at iteration 729 = 5.22186387154867
#
# Cost at iteration 730 = 5.220492382290384
#
# Cost at iteration 731 = 5.219121330662612
#
# Cost at iteration 732 = 5.217750716525327
#
# Cost at iteration 733 = 5.216380539739641
#
# Cost at iteration 734 = 5.21501080016594
#
# Cost at iteration 735 = 5.21364149766465
#
# Cost at iteration 736 = 5.212272632096244
#
# Cost at iteration 737 = 5.210904203318514
#
# Cost at iteration 738 = 5.209536211191093
#
# Cost at iteration 739 = 5.208168655578228
#
# Cost at iteration 740 = 5.206801536340569
#
# Cost at iteration 741 = 5.205434853338809
#
# Cost at iteration 742 = 5.20406860643369
#
# Cost at iteration 743 = 5.2027027954859975
#
# Cost at iteration 744 = 5.201337420356557
#
# Cost at iteration 745 = 5.199972480906244
#
# Cost at iteration 746 = 5.1986079769959765
#
# Cost at iteration 747 = 5.197243908486715
#
# Cost at iteration 748 = 5.195880275239464
#
# Cost at iteration 749 = 5.194517077115277
#
# Cost at iteration 750 = 5.193154313975249
#
# Cost at iteration 751 = 5.191791985680519
#
# Cost at iteration 752 = 5.190430092092269
#
# Cost at iteration 753 = 5.18906863307173
#
# Cost at iteration 754 = 5.187707608480173
#
# Cost at iteration 755 = 5.186347018178917
#
# Cost at iteration 756 = 5.184986862029319
#
# Cost at iteration 757 = 5.183627139892787
#
# Cost at iteration 758 = 5.182267851630771
#
# Cost at iteration 759 = 5.180908997104762
#
# Cost at iteration 760 = 5.179550576176302
#
# Cost at iteration 761 = 5.1781925887069695
#
# Cost at iteration 762 = 5.176835034558394
#
# Cost at iteration 763 = 5.175477913592244
#
# Cost at iteration 764 = 5.174121225670238
#
# Cost at iteration 765 = 5.17276497065413
#
# Cost at iteration 766 = 5.171409148405726
#
# Cost at iteration 767 = 5.1700537587868745
#
# Cost at iteration 768 = 5.168698801659463
#
# Cost at iteration 769 = 5.167344276885431
#
# Cost at iteration 770 = 5.165990184326756
#
# Cost at iteration 771 = 5.164636523845463
#
# Cost at iteration 772 = 5.163283295303619
#
# Cost at iteration 773 = 5.161930498563335
#
# Cost at iteration 774 = 5.160578133486768
#
# Cost at iteration 775 = 5.159226199935467
#
# Cost at iteration 776 = 5.15787469774244
#
# Cost at iteration 777 = 5.156523626798835
#
# Cost at iteration 778 = 5.1551729869679255
#
# Cost at iteration 779 = 5.153822778112091
#
# Cost at iteration 780 = 5.152473000093748
#
# Cost at iteration 781 = 5.151123652775363
#
# Cost at iteration 782 = 5.149774736019442
#
# Cost at iteration 783 = 5.148426249688535
#
# Cost at iteration 784 = 5.147078193617019
#
# Cost at iteration 785 = 5.145730567673001
#
# Cost at iteration 786 = 5.144383371741778
#
# Cost at iteration 787 = 5.143036605686075
#
# Cost at iteration 788 = 5.141690269368663
#
# Cost at iteration 789 = 5.140344362652359
#
# Cost at iteration 790 = 5.13899888540002
#
# Cost at iteration 791 = 5.137653837474548
#
# Cost at iteration 792 = 5.13630921873889
#
# Cost at iteration 793 = 5.134965029056036
#
# Cost at iteration 794 = 5.133621268289021
#
# Cost at iteration 795 = 5.132277936300919
#
# Cost at iteration 796 = 5.130935032954856
#
# Cost at iteration 797 = 5.129592558092936
#
# Cost at iteration 798 = 5.128250511593654
#
# Cost at iteration 799 = 5.126908893325961
#
# Cost at iteration 800 = 5.1255677031531555
#
# Cost at iteration 801 = 5.124226940938574
#
# Cost at iteration 802 = 5.1228866065456025
#
# Cost at iteration 803 = 5.121546699837667
#
# Cost at iteration 804 = 5.120207220678239
#
# Cost at iteration 805 = 5.11886816893083
#
# Cost at iteration 806 = 5.117529544459001
#
# Cost at iteration 807 = 5.1161913471263505
#
# Cost at iteration 808 = 5.114853576796526
#
# Cost at iteration 809 = 5.113516233333215
#
# Cost at iteration 810 = 5.112179316600148
#
# Cost at iteration 811 = 5.110842826461104
#
# Cost at iteration 812 = 5.109506762759743
#
# Cost at iteration 813 = 5.108171125372796
#
# Cost at iteration 814 = 5.106835914171384
#
# Cost at iteration 815 = 5.1055011290194585
#
# Cost at iteration 816 = 5.104166769781009
#
# Cost at iteration 817 = 5.102832836320075
#
# Cost at iteration 818 = 5.101499328500734
#
# Cost at iteration 819 = 5.1001662461871105
#
# Cost at iteration 820 = 5.098833589243371
#
# Cost at iteration 821 = 5.097501357533725
#
# Cost at iteration 822 = 5.0961695509224265
#
# Cost at iteration 823 = 5.094838169273771
#
# Cost at iteration 824 = 5.0935072124521
#
# Cost at iteration 825 = 5.0921766803217965
#
# Cost at iteration 826 = 5.090846572747287
#
# Cost at iteration 827 = 5.089516889593041
#
# Cost at iteration 828 = 5.088187630723572
#
# Cost at iteration 829 = 5.086858796003435
#
# Cost at iteration 830 = 5.085530385297234
#
# Cost at iteration 831 = 5.084202398469607
#
# Cost at iteration 832 = 5.082874835385243
#
# Cost at iteration 833 = 5.081547695908871
#
# Cost at iteration 834 = 5.080220979905264
#
# Cost at iteration 835 = 5.078894687239236
#
# Cost at iteration 836 = 5.077568817775648
#
# Cost at iteration 837 = 5.076243371379402
#
# Cost at iteration 838 = 5.074918347915442
#
# Cost at iteration 839 = 5.073593747248756
#
# Cost at iteration 840 = 5.072269569244378
#
# Cost at iteration 841 = 5.070945813767381
#
# Cost at iteration 842 = 5.069622480682882
#
# Cost at iteration 843 = 5.068299569856044
#
# Cost at iteration 844 = 5.066977081152067
#
# Cost at iteration 845 = 5.065655014436202
#
# Cost at iteration 846 = 5.0643333695737365
#
# Cost at iteration 847 = 5.063012146430005
#
# Cost at iteration 848 = 5.061691344870383
#
# Cost at iteration 849 = 5.0603709647602875
#
# Cost at iteration 850 = 5.059051005965182
#
# Cost at iteration 851 = 5.057731468350572
#
# Cost at iteration 852 = 5.056412351782003
#
# Cost at iteration 853 = 5.055093656125069
#
# Cost at iteration 854 = 5.053775381245402
#
# Cost at iteration 855 = 5.052457527008678
#
# Cost at iteration 856 = 5.051140093280617
#
# Cost at iteration 857 = 5.0498230799269805
#
# Cost at iteration 858 = 5.048506486813576
#
# Cost at iteration 859 = 5.047190313806248
#
# Cost at iteration 860 = 5.045874560770892
#
# Cost at iteration 861 = 5.044559227573437
#
# Cost at iteration 862 = 5.043244314079863
#
# Cost at iteration 863 = 5.041929820156187
#
# Cost at iteration 864 = 5.040615745668474
#
# Cost at iteration 865 = 5.039302090482827
#
# Cost at iteration 866 = 5.037988854465391
#
# Cost at iteration 867 = 5.036676037482362
#
# Cost at iteration 868 = 5.03536363939997
#
# Cost at iteration 869 = 5.034051660084491
#
# Cost at iteration 870 = 5.0327400994022415
#
# Cost at iteration 871 = 5.031428957219588
#
# Cost at iteration 872 = 5.030118233402929
#
# Cost at iteration 873 = 5.028807927816489
#
# Cost at iteration 874 = 5.027498040304328
#
# Cost at iteration 875 = 5.026188570757567
#
# Cost at iteration 876 = 5.024879519042777
#
# Cost at iteration 877 = 5.023570885026577
#
# Cost at iteration 878 = 5.0222626685580645
#
# Cost at iteration 879 = 5.020954869511923
#
# Cost at iteration 880 = 5.01964748776441
#
# Cost at iteration 881 = 5.018340523182317
#
# Cost at iteration 882 = 5.017033975626269
#
# Cost at iteration 883 = 5.015727844949081
#
# Cost at iteration 884 = 5.014422131037866
#
# Cost at iteration 885 = 5.013116833759578
#
# Cost at iteration 886 = 5.011811952981218
#
# Cost at iteration 887 = 5.0105074885698295
#
# Cost at iteration 888 = 5.009203440392497
#
# Cost at iteration 889 = 5.007899808316347
#
# Cost at iteration 890 = 5.006596592208552
#
# Cost at iteration 891 = 5.00529379193632
#
# Cost at iteration 892 = 5.00399140736691
#
# Cost at iteration 893 = 5.002689438367617
#
# Cost at iteration 894 = 5.001387884805781
#
# Cost at iteration 895 = 5.000086746548783
#
# Cost at iteration 896 = 4.99878602346344
#
# Cost at iteration 897 = 4.997485715417259
#
# Cost at iteration 898 = 4.996185822278313
#
# Cost at iteration 899 = 4.994886343914152
#
# Cost at iteration 900 = 4.993587280192371
#
# Cost at iteration 901 = 4.992288630980605
#
# Cost at iteration 902 = 4.990990396146532
#
# Cost at iteration 903 = 4.989692575557871
#
# Cost at iteration 904 = 4.988395169082386
#
# Cost at iteration 905 = 4.987098176587882
#
# Cost at iteration 906 = 4.985801597942205
#
# Cost at iteration 907 = 4.984505432988266
#
# Cost at iteration 908 = 4.983209681618481
#
# Cost at iteration 909 = 4.981914343701257
#
# Cost at iteration 910 = 4.98061941910461
#
# Cost at iteration 911 = 4.979324907696597
#
# Cost at iteration 912 = 4.978030809345318
#
# Cost at iteration 913 = 4.976737123918916
#
# Cost at iteration 914 = 4.975443851285574
#
# Cost at iteration 915 = 4.9741509913135165
#
# Cost at iteration 916 = 4.972858543857111
#
# Cost at iteration 917 = 4.9715665087849255
#
# Cost at iteration 918 = 4.9702748859788946
#
# Cost at iteration 919 = 4.968983675307411
#
# Cost at iteration 920 = 4.967692876638912
#
# Cost at iteration 921 = 4.966402489837467
#
# Cost at iteration 922 = 4.9651125147531605
#
# Cost at iteration 923 = 4.9638229512773355
#
# Cost at iteration 924 = 4.9625337992785985
#
# Cost at iteration 925 = 4.961245058625595
#
# Cost at iteration 926 = 4.959956729187013
#
# Cost at iteration 927 = 4.958668810831584
#
# Cost at iteration 928 = 4.957381303428079
#
# Cost at iteration 929 = 4.956094206845314
#
# Cost at iteration 930 = 4.954807520952144
#
# Cost at iteration 931 = 4.953521245617466
#
# Cost at iteration 932 = 4.952235380710222
#
# Cost at iteration 933 = 4.950949926099393
#
# Cost at iteration 934 = 4.9496648816540025
#
# Cost at iteration 935 = 4.948380247243113
#
# Cost at iteration 936 = 4.947096022735836
#
# Cost at iteration 937 = 4.945812208001317
#
# Cost at iteration 938 = 4.944528802908749
#
# Cost at iteration 939 = 4.943245807327363
#
# Cost at iteration 940 = 4.941963221126435
#
# Cost at iteration 941 = 4.940681044175279
#
# Cost at iteration 942 = 4.939399276343254
#
# Cost at iteration 943 = 4.93811791749976
#
# Cost at iteration 944 = 4.936836967514235
#
# Cost at iteration 945 = 4.9355564262561655
#
# Cost at iteration 946 = 4.934276293595075
#
# Cost at iteration 947 = 4.932996569400529
#
# Cost at iteration 948 = 4.931717253542134
#
# Cost at iteration 949 = 4.930438345889542
#
# Cost at iteration 950 = 4.929159846312443
#
# Cost at iteration 951 = 4.92788175468057
#
# Cost at iteration 952 = 4.9266040708636964
#
# Cost at iteration 953 = 4.925326794731638
#
# Cost at iteration 954 = 4.924049926154255
#
# Cost at iteration 955 = 4.922773465001442
#
# Cost at iteration 956 = 4.921497411143144
#
# Cost at iteration 957 = 4.920221764449339
#
# Cost at iteration 958 = 4.918946524790052
#
# Cost at iteration 959 = 4.91767169203535
#
# Cost at iteration 960 = 4.9163972660553386
#
# Cost at iteration 961 = 4.915123246720165
#
# Cost at iteration 962 = 4.913849633900019
#
# Cost at iteration 963 = 4.912576427463181
#
# Cost at iteration 964 = 4.911303627257602
#
# Cost at iteration 965 = 4.910031233177809
#
# Cost at iteration 966 = 4.908759245094156
#
# Cost at iteration 967 = 4.907487662877045
#
# Cost at iteration 968 = 4.90621648639691
#
# Cost at iteration 969 = 4.90494571552423
#
# Cost at iteration 970 = 4.903675350129527
#
# Cost at iteration 971 = 4.902405390083365
#
# Cost at iteration 972 = 4.901135835256343
#
# Cost at iteration 973 = 4.899866685488227
#
# Cost at iteration 974 = 4.898597940653762
#
# Cost at iteration 975 = 4.897329600650371
#
# Cost at iteration 976 = 4.896061665331453
#
# Cost at iteration 977 = 4.894794134572276
#
# Cost at iteration 978 = 4.893527008256536
#
# Cost at iteration 979 = 4.892260286230796
#
# Cost at iteration 980 = 4.89099396838825
#
# Cost at iteration 981 = 4.889728054601887
#
# Cost at iteration 982 = 4.888462544742724
#
# Cost at iteration 983 = 4.887197438681816
#
# Cost at iteration 984 = 4.885932736290264
#
# Cost at iteration 985 = 4.884668437439205
#
# Cost at iteration 986 = 4.883404541999822
#
# Cost at iteration 987 = 4.882141049843336
#
# Cost at iteration 988 = 4.880877960830504
#
# Cost at iteration 989 = 4.8796152748258805
#
# Cost at iteration 990 = 4.878352991718006
#
# Cost at iteration 991 = 4.8770911113782685
#
# Cost at iteration 992 = 4.875829633671239
#
# Cost at iteration 993 = 4.874568558453995
#
# Cost at iteration 994 = 4.8733078856192344
#
# Cost at iteration 995 = 4.872047615038507
#
# Cost at iteration 996 = 4.870787746583403
#
# Cost at iteration 997 = 4.869528280110501
#
# Cost at iteration 998 = 4.868269215494119
#
# Cost at iteration 999 = 4.867010552618323
#
# Cost at iteration 1000 = 4.865752291354871
#
# [[0.27674917 0.27255008 0.26947401]
#  [0.27674924 0.27254986 0.26947444]
#  [0.2767489  0.27255102 0.26947219]
#  [0.27674885 0.27255118 0.26947188]
#  [0.27674915 0.27255016 0.26947386]
#  [0.27674887 0.27255112 0.269472  ]
#  [0.27674897 0.27255079 0.26947263]
#  [0.27674906 0.27255046 0.26947328]
#  [0.27674897 0.27255078 0.26947265]
#  [0.27674882 0.27255128 0.26947168]
#  [0.27674875 0.27255155 0.26947116]
#  [0.27674905 0.27255049 0.26947323]
#  [0.2767487  0.2725517  0.26947088]
#  [0.27674891 0.27255097 0.26947229]
#  [0.27674963 0.27254853 0.26947703]
#  [0.27674836 0.27255288 0.26946858]
#  [0.27674881 0.27255131 0.26947162]
#  [0.27674897 0.27255078 0.26947266]
#  [0.27674951 0.27254892 0.26947628]
#  [0.27674883 0.27255127 0.26947171]
#  [0.2767491  0.27255033 0.26947354]]
